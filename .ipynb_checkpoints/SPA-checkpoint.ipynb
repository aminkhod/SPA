# %%
from docx import Document
from docx.shared import Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH 
from docx.shared import Pt
from docx.shared import RGBColor
import pandas as pd
import numpy as np

# %%
track = pd.read_csv('Tracking Sheet output.csv',encoding='latin1')
track
# Out:
#              REF                                  repExporter  \
# 0      MBBM-0228                                          NaN
# 1      MBBM-0254                    C T A GENERAL TRADING LLC
# 2      MBBM-0265                    C T A GENERAL TRADING LLC
# 3      MBBM-0226          DREAM GLORY ELECTRONICS TRADING LLC
# 4      MBBM-0245                     HASSAN SAFAR TRADING LLC
# 5      MBBM-0230                                          NaN
# 6      MBBM-0229                                          NaN
# 7      MBBM-0241                             MAGNUM IMPEX FZE
# 8      MBBM-0267                                          NaN
# 9      MBBM-0221              OCEAN PEARL GENERAL TRADING LLC
# 10     MBBM-0225              OCEAN PEARL GENERAL TRADING LLC
# 11     MBBM-0227              OCEAN PEARL GENERAL TRADING LLC
# 12     MBBM-0231              OCEAN PEARL GENERAL TRADING LLC
# 13     MBBM-0268                                          NaN
# 14     MBBM-0259  PHENOMENA INTERNATIONAL GENERAL TRADING LLC
# 15     MBBM-0232  PHENOMENA INTERNATIONAL GENERAL TRADING LLC
# 16     MBBM-0233                          RABARBA TRADING FZE
# 17     MBBM-0244                          RABARBA TRADING FZE
# 18     MBBM-0260                          RABARBA TRADING FZE
# 19     MBBM-0235                          S A R V TRADING FZE
# 20     MBBM-0243                SNOW LINE GENERAL TRADING LLC
# 21     MBBM-0252                SNOW LINE GENERAL TRADING LLC
# 22     MBBM-0253                SNOW LINE GENERAL TRADING LLC
# 23     MBBM-0263                SNOW LINE GENERAL TRADING LLC
# 24     MBBM-0251                                          NaN
# 25     MBBM-0234                      TOP PACIFIC TRADING LLC
# 26  MBBM-0264-CL                       VANO JERRY TRADING LLC
# 27  MBBM-0242-CL                       VANO JERRY TRADING LLC
# 28  MBBM-0224-CL                 RONGWEI GARMENTS TRADING LLC
# 29  MBBM-0256-CL                     PEARL CHEMTEX ARABIA FZC
# 30  MBBM-0248-CL                    OBASTA TSUKAI TRADING LLC
# 31  MBBM-0262-CL                       JERRY VANO TRADING LLC
# 32  MBBM-0237-CL       CGT COMMODITIES AND BUILDING MATERIALS
#
#                       cityOfRepExporter  \
# 0                                   NaN
# 1           Dubai, United Arab Emirates
# 2           Dubai, United Arab Emirates
# 3                          Dubai, U.A.E
# 4                          Dubai, U.A.E
# 5                                   NaN
# 6                                   NaN
# 7         Sharjah, United Arab Emirates
# 8                                   NaN
# 9           Dubai, United Arab Emirates
# 10          Dubai, United Arab Emirates
# 11          Dubai, United Arab Emirates
# 12          Dubai, United Arab Emirates
# 13                                  NaN
# 14          Dubai, United Arab Emirates
# 15          Dubai, United Arab Emirates
# 16  Umm Al Quwain, United Arab Emirates
# 17  Umm Al Quwain, United Arab Emirates
# 18  Umm Al Quwain, United Arab Emirates
# 19                         Dubai, U.A.E
# 20          Dubai, United Arab Emirates
# 21          Dubai, United Arab Emirates
# 22          Dubai, United Arab Emirates
# 23          Dubai, United Arab Emirates
# 24                                  NaN
# 25                         Dubai, U.A.E
# 26                         Dubai, U.A.E
# 27                         Dubai, U.A.E
# 28                         Dubai, U.A.E
# 29                         Dubai, U.A.E
# 30                         Dubai, U.A.E
# 31                         Dubai, U.A.E
# 32                         Dubai, U.A.E
#
#                                              exporter  \
# 0                          AGRAWAL MARBLE AND GRANITE
# 1                                      LAADER BERG AS
# 2                                      LAADER BERG AS
# 3                                      LAMBRECHT HOUT
# 4                   ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 5             HEFEI W I SCIENCE AND TECHNOLOGY CO LTD
# 6              HUNAN HIGH TECH DEVELOPMENT CO LIMITED
# 7                   YUTRON TECHNOLOGY COMPANY LIMITED
# 8       NINGBO FLOURISHING PRECISION ELECTRON CO.,LTD
# 9   EVER GREEN MAKINA SANAYI IC VE DIS TICARET LIM...
# 10  EVER GREEN MAKINA SANAYI IC VE DIS TICARET LIM...
# 11  EVER GREEN MAKINA SANAYI IC VE DIS TICARET LIM...
# 12  EVER GREEN MAKINA SANAYI IC VE DIS TICARET LIM...
# 13                                      OPTIBELT GMBH
# 14       CHANGZOU MAITE DECORATIVE MATERIAL CO., LTD.
# 15       CHANGZOU MAITE DECORATIVE MATERIAL CO., LTD.
# 16  SOMER ITHALAT IHRACAT SANAYI VE TICARET LIMITE...
# 17  SOMER ITHALAT IHRACAT SANAYI VE TICARET LIMITE...
# 18  SOMER ITHALAT IHRACAT SANAYI VE TICARET LIMITE...
# 19                              GOTAJ CERAMIC SDN BHD
# 20                      WHENZHOU CHANGS INTERNATIONAL
# 21                      WHENZHOU CHANGS INTERNATIONAL
# 22                      WHENZHOU CHANGS INTERNATIONAL
# 23                      WHENZHOU CHANGS INTERNATIONAL
# 24                                    SUN SAFE MFG CO
# 25                           AL JABOR TRADING COMPANY
# 26                                     MENGYANG GROUP
# 27  SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 28                                       INDIA CEMENT
# 29                                   RHI DINARIS GMBH
# 30                  AnHuiarts & Crafts imp.exp.Co.Ltd
# 31                               ADII SYNERGY SDN BHD
# 32               HOWELL CLEAN APPLIANCES (HK) LIMITED
#
#               cityOfExporter                            importer  \
# 0           Rajasthan, India  COLORGRES BUILDING MATERIAL CO LTD
# 1            Alesund, Norway  COLORGRES BUILDING MATERIAL CO LTD
# 2            Alesund, Norway  COLORGRES BUILDING MATERIAL CO LTD
# 3           Mortsel, Belgium  COLORGRES BUILDING MATERIAL CO LTD
# 4                Anhui,China  COLORGRES BUILDING MATERIAL CO LTD
# 5               Hefei, China  COLORGRES BUILDING MATERIAL CO LTD
# 6           Hong Kong, China  COLORGRES BUILDING MATERIAL CO LTD
# 7            Hongkong, China  COLORGRES BUILDING MATERIAL CO LTD
# 8              Ningbo, China  COLORGRES BUILDING MATERIAL CO LTD
# 9            Antalya, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 10           Antalya, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 11           Antalya, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 12           Antalya, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 13           Hoxter, Germany  COLORGRES BUILDING MATERIAL CO LTD
# 14      Jiangsu Sheng, China  COLORGRES BUILDING MATERIAL CO LTD
# 15      Jiangsu Sheng, China  COLORGRES BUILDING MATERIAL CO LTD
# 16          Istanbul, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 17          Istanbul, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 18          Istanbul, Turkey  COLORGRES BUILDING MATERIAL CO LTD
# 19        Selangor, Malaysia  COLORGRES BUILDING MATERIAL CO LTD
# 20           Whenzhou, China  COLORGRES BUILDING MATERIAL CO LTD
# 21           Whenzhou, China  COLORGRES BUILDING MATERIAL CO LTD
# 22           Whenzhou, China  COLORGRES BUILDING MATERIAL CO LTD
# 23           Whenzhou, China  COLORGRES BUILDING MATERIAL CO LTD
# 24  Gyeonggi-Do, South Korea  COLORGRES BUILDING MATERIAL CO LTD
# 25               Doha, Qatar  COLORGRES BUILDING MATERIAL CO LTD
# 26            Jiangsu, China  COLORGRES BUILDING MATERIAL CO LTD
# 27          Liaocheng, China  COLORGRES BUILDING MATERIAL CO LTD
# 28         Tamil Nadu, India  COLORGRES BUILDING MATERIAL CO LTD
# 29        Wiesbaden, Germany  COLORGRES BUILDING MATERIAL CO LTD
# 30               Anhui,China  COLORGRES BUILDING MATERIAL CO LTD
# 31    Kuala Lumpur, Malaysia  COLORGRES BUILDING MATERIAL CO LTD
# 32         Hong Kong , China  COLORGRES BUILDING MATERIAL CO LTD
#
#    cityOfImporter                                  repImporter  \
# 0   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 1   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 2   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 3   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 4   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 5   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 6   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 7   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 8   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 9   Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 10  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 11  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 12  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 13  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 14  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 15  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 16  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 17  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 18  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 19  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 20  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 21  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 22  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 23  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 24  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 25  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 26  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 27  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 28  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 29  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 30  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 31  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
# 32  Foshan, China  MAGIC BRICKS BUILDING MATERIALS TRADING LLC
#
#    cityOfrepImporter               Origin  ...  \
# 0       Dubai, U.A.E        Origin: India  ...
# 1       Dubai, U.A.E       Origin: Norway  ...
# 2       Dubai, U.A.E       Origin: Norway  ...
# 3       Dubai, U.A.E      Origin: Belgium  ...
# 4       Dubai, U.A.E         Origin: hina  ...
# 5       Dubai, U.A.E        Origin: China  ...
# 6       Dubai, U.A.E        Origin: China  ...
# 7       Dubai, U.A.E        Origin: China  ...
# 8       Dubai, U.A.E        Origin: China  ...
# 9       Dubai, U.A.E       Origin: Turkey  ...
# 10      Dubai, U.A.E       Origin: Turkey  ...
# 11      Dubai, U.A.E       Origin: Turkey  ...
# 12      Dubai, U.A.E       Origin: Turkey  ...
# 13      Dubai, U.A.E      Origin: Germany  ...
# 14      Dubai, U.A.E        Origin: China  ...
# 15      Dubai, U.A.E        Origin: China  ...
# 16      Dubai, U.A.E       Origin: Turkey  ...
# 17      Dubai, U.A.E       Origin: Turkey  ...
# 18      Dubai, U.A.E       Origin: Turkey  ...
# 19      Dubai, U.A.E     Origin: Malaysia  ...
# 20      Dubai, U.A.E        Origin: China  ...
# 21      Dubai, U.A.E        Origin: China  ...
# 22      Dubai, U.A.E        Origin: China  ...
# 23      Dubai, U.A.E        Origin: China  ...
# 24      Dubai, U.A.E  Origin: South Korea  ...
# 25      Dubai, U.A.E        Origin: Qatar  ...
# 26      Dubai, U.A.E        Origin: China  ...
# 27      Dubai, U.A.E        Origin: China  ...
# 28      Dubai, U.A.E        Origin: India  ...
# 29      Dubai, U.A.E      Origin: Germany  ...
# 30      Dubai, U.A.E         Origin: hina  ...
# 31      Dubai, U.A.E     Origin: Malaysia  ...
# 32      Dubai, U.A.E        Origin: China  ...
#
#                                       amount in words origin without origin  \
# 0   Amount in words : Two Thousand Nine Hundred Fo...                 India
# 1   Amount in words : One Million Four Hundred Ten...                Norway
# 2   Amount in words : Four Hundred Fifty Five Thou...                Norway
# 3   Amount in words : Three Hundred Forty Thousand...               Belgium
# 4   Amount in words : One Million Six Hundred Twen...                  hina
# 5   Amount in words : Nineteen Thousand Euros Only...                 China
# 6    Amount in words : Three Thousand Euros Only - 30                 China
# 7   Amount in words : One Million Nineteen Thousan...                 China
# 8   Amount in words : Sixty Five Thousand U.S Doll...                 China
# 9   Amount in words : Three Hundred Fifty Three Th...                Turkey
# 10  Amount in words : Three Hundred Fifty Three Th...                Turkey
# 11  Amount in words : Three Thousand Fifty Six 20....                Turkey
# 12  Amount in words : Fifty Thousand Dirhams Only ...                Turkey
# 13  Amount in words : Forty Six Thousand Eight Hun...               Germany
# 14  Amount in words : Four Hundred Seventy Three T...                 China
# 15  Amount in words : Nine Hundred Sixty Thousand ...                 China
# 16  Amount in words : Five Hundred Forty Eight Tho...                Turkey
# 17  Amount in words : Five Hundred Thirty Seven Th...                Turkey
# 18  Amount in words : Four Hundred Thousand Dirham...                Turkey
# 19  Amount in words : Five Hundred Nine Thousand F...              Malaysia
# 20  Amount in words : Seven Hundred Seventy Six Th...                 China
# 21  Amount in words : Three Hundred Twenty Thousan...                 China
# 22  Amount in words : One Million Seven Hundred On...                 China
# 23  Amount in words : Five Hundred Thousand Five H...                 China
# 24  Amount in words : Fifty Thousand Five Hundred ...           South Korea
# 25  Amount in words : Five Hundred Ninety Six Thou...                 Qatar
# 26  Amount in words : Three Million Eight Hundred ...                 China
# 27  Amount in words : Five Million Two Hundred Six...                 China
# 28   Amount in words : Five Million Dirhams Only - 30                 India
# 29  Amount in words : Two Hundred Sixty Three Thou...               Germany
# 30  Amount in words : Three Million Fifty Thousand...                  hina
# 31  Amount in words : Two Million Three Hundred Si...              Malaysia
# 32  Amount in words : One Million Seven Hundred Ei...                 China
#
#      loading without loading discharge without discharge  \
# 0           Rajasthan, India               Foshan, China
# 1            Alesund, Norway               Foshan, China
# 2            Alesund, Norway               Foshan, China
# 3           Mortsel, Belgium               Foshan, China
# 4                Anhui,China               Foshan, China
# 5               Hefei, China               Foshan, China
# 6           Hong Kong, China               Foshan, China
# 7            Hongkong, China               Foshan, China
# 8              Ningbo, China               Foshan, China
# 9            Antalya, Turkey               Foshan, China
# 10           Antalya, Turkey               Foshan, China
# 11           Antalya, Turkey               Foshan, China
# 12           Antalya, Turkey               Foshan, China
# 13           Hoxter, Germany               Foshan, China
# 14      Jiangsu Sheng, China               Foshan, China
# 15      Jiangsu Sheng, China               Foshan, China
# 16          Istanbul, Turkey               Foshan, China
# 17          Istanbul, Turkey               Foshan, China
# 18          Istanbul, Turkey               Foshan, China
# 19        Selangor, Malaysia               Foshan, China
# 20           Whenzhou, China               Foshan, China
# 21           Whenzhou, China               Foshan, China
# 22           Whenzhou, China               Foshan, China
# 23           Whenzhou, China               Foshan, China
# 24  Gyeonggi-Do, South Korea               Foshan, China
# 25               Doha, Qatar               Foshan, China
# 26            Jiangsu, China               Foshan, China
# 27          Liaocheng, China               Foshan, China
# 28         Tamil Nadu, India               Foshan, China
# 29        Wiesbaden, Germany               Foshan, China
# 30               Anhui,China               Foshan, China
# 31    Kuala Lumpur, Malaysia               Foshan, China
# 32         Hong Kong , China               Foshan, China
#
#    country of manufacture  country of destination        date of PO  \
# 0                   INDIA                   CHINA  26 February 2019
# 1                  NORWAY                   CHINA  23 February 2019
# 2                  NORWAY                   CHINA  23 February 2019
# 3                 BELGIUM                   CHINA  22 February 2019
# 4                    HINA                   CHINA  19 February 2019
# 5                   CHINA                   CHINA  23 February 2019
# 6                   CHINA                   CHINA  22 February 2019
# 7                   CHINA                   CHINA  15 February 2019
# 8                   CHINA                   CHINA  15 February 2019
# 9                  TURKEY                   CHINA  20 February 2019
# 10                 TURKEY                   CHINA  22 February 2019
# 11                 TURKEY                   CHINA  20 February 2019
# 12                 TURKEY                   CHINA  07 February 2019
# 13                GERMANY                   CHINA  23 February 2019
# 14                  CHINA                   CHINA  20 February 2019
# 15                  CHINA                   CHINA  07 February 2019
# 16                 TURKEY                   CHINA  07 February 2019
# 17                 TURKEY                   CHINA  18 February 2019
# 18                 TURKEY                   CHINA  21 February 2019
# 19               MALAYSIA                   CHINA  08 February 2019
# 20                  CHINA                   CHINA  18 February 2019
# 21                  CHINA                   CHINA  22 February 2019
# 22                  CHINA                   CHINA  23 February 2019
# 23                  CHINA                   CHINA  23 February 2019
# 24            SOUTH KOREA                   CHINA  21 February 2019
# 25                  QATAR                   CHINA  08 February 2019
# 26                  CHINA                   CHINA  20 February 2019
# 27                  CHINA                   CHINA  15 February 2019
# 28                  INDIA                   CHINA  21 February 2019
# 29                GERMANY                   CHINA  11 February 2019
# 30                   HINA                   CHINA  19 February 2019
# 31               MALAYSIA                   CHINA  21 February 2019
# 32                  CHINA                   CHINA  09 February 2019
#
#           date of SQ     date of PI date of CIorPL
# 0   25 February 2019  23 March 2019  02 April 2019
# 1   22 February 2019  20 March 2019  30 March 2019
# 2   22 February 2019  20 March 2019  30 March 2019
# 3   21 February 2019  19 March 2019  29 March 2019
# 4   18 February 2019  16 March 2019  26 March 2019
# 5   22 February 2019  20 March 2019  30 March 2019
# 6   21 February 2019  19 March 2019  29 March 2019
# 7   14 February 2019  12 March 2019  22 March 2019
# 8   14 February 2019  12 March 2019  22 March 2019
# 9   19 February 2019  17 March 2019  27 March 2019
# 10  21 February 2019  19 March 2019  29 March 2019
# 11  19 February 2019  17 March 2019  27 March 2019
# 12  06 February 2019  04 March 2019  14 March 2019
# 13  22 February 2019  20 March 2019  30 March 2019
# 14  19 February 2019  17 March 2019  27 March 2019
# 15  06 February 2019  04 March 2019  14 March 2019
# 16  06 February 2019  04 March 2019  14 March 2019
# 17  17 February 2019  15 March 2019  25 March 2019
# 18  20 February 2019  18 March 2019  28 March 2019
# 19  07 February 2019  05 March 2019  15 March 2019
# 20  17 February 2019  15 March 2019  25 March 2019
# 21  21 February 2019  19 March 2019  29 March 2019
# 22  22 February 2019  20 March 2019  30 March 2019
# 23  22 February 2019  20 March 2019  30 March 2019
# 24  20 February 2019  18 March 2019  28 March 2019
# 25  07 February 2019  05 March 2019  15 March 2019
# 26  19 February 2019  17 March 2019  27 March 2019
# 27  14 February 2019  12 March 2019  22 March 2019
# 28  20 February 2019  18 March 2019  28 March 2019
# 29  10 February 2019  08 March 2019  18 March 2019
# 30  18 February 2019  16 March 2019  26 March 2019
# 31  20 February 2019  18 March 2019  28 March 2019
# 32  08 February 2019  06 March 2019  16 March 2019
#
# [33 rows x 52 columns]

# %%
# client = pd.read_csv('2018 ABACUS CLIENTS.csv')
# client.plot()

# %%
# def lcs(X , Y): 
#     # find the length of the strings 
#     m = len(X) 
#     n = len(Y) 
  
#     # declaring the array for storing the dp values 
#     L = [[None]*(n+1) for i in range(m+1)] 
  
#     """Following steps build L[m+1][n+1] in bottom up fashion 
#     Note: L[i][j] contains length of LCS of X[0..i-1] 
#     and Y[0..j-1]"""
#     for i in range(m+1): 
#         for j in range(n+1): 
#             if i == 0 or j == 0 : 
#                 L[i][j] = 0
#             elif X[i-1] == Y[j-1]: 
#                 L[i][j] = L[i-1][j-1]+1
#             else: 
#                 L[i][j] = max(L[i-1][j] , L[i][j-1]) 
#     return L[m][n] 
# #end of function lcs

# %%
# def getClientRef(c, clientlist):
#     num = str(clientlist.loc[c,'SR. NO.']) + '.'
#     for char in clientlist.loc[c,'LIST OF COMPANY']:
#         if char != '.':
#             num = num + char
#         else:
#             break
#     return num
    
# def bestmatch(candid,clientlist):
#     # Remove all bad charachters.
#     candid = ''.join(e for e in candid if e.isalnum())
#     c = 0
#     maxAl = 0
#     candidRow = []
#     num = ''
#     maxLCStoClient = 0
#     for client in clientlist['LIST OF COMPANY']:

#         candidLcs = lcs(candid.lower(), client.lower())
#         LCStoClient = candidLcs / len(client)
#         if (candidLcs == len(candid)):
#             if (maxLCStoClient < LCStoClient):
#                 candidRow = list(clientlist.iloc[c])
#                 num = getClientRef(c, clientlist)
#                 maxLCStoClient = LCStoClient
#         c+=1


#     return num, candidRow
# bestmatch('ANA GENERAL TRADING LLC',client)

# %%
# #Finding major company of REP.,
# def majorCoOfREP(candid,client):,
#     bestmatch(candid,client),
#     return ''

# %%
def ordinal(date):
    if date == 1:
        ordin = 'ST'
    elif date == 2:
        ordin = 'ND'
    elif date == 3:
        ordin = 'RD'
    else:
        ordin = 'TH'
    return ordin

# %%
def amontformat(totamount):
    totamount = str(totamount)
    c = len(totamount) - 1
    buf = ''
    buf1 = ''
    for i in range(c+1):
        if totamount[c - i] == '.':
            buf = totamount[c - i] + buf
            try:
                totamount1 = totamount.replace(buf,'')
#                 print(buf , totamount1)
            except:
                1+1
            if len(buf)<2:
                buf = buf[1:]
                buf = '.' +'00'
            elif len(buf) < 3:
                buf = buf[1:]
                buf = '.' + buf +'0'
            buf =  buf[:3]
            c1 = len(totamount1) -1
            count = 1
            
            for j in range(c1+1):
                if (count%3 == 0) and (j!=c1) :
                    buf1 = ',' + totamount1[c1 - j] + buf1
                else:
                    buf1 = totamount1[c1 - j] + buf1
                count += 1
#             print(buf1)
            break
        else:
            buf = totamount[c - i] + buf
    return buf1 + buf

# %%
# amontformat(877000.0)

# %%
def produceDocxFile(num,ref):
    #Title
    document =  Document('SPA.docx')
    paragraph = document.add_paragraph('\n \n \n')
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('PURCHASE AND SALE AGREEMENT')
    run.bold = True
    font = run.font
    font.name = 'Arial'
    font.size = Pt(14)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    style = document.styles['Normal']
    font = style.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('BY AND BETWEEN')
    run.bold = True

    #buyer
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run(str(buyerName)+' - '+buyerCity)
    run.bold = True

    #repBuyer
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run1= paragraph.add_run('Represented by: ')

    run= paragraph.add_run(str(buyerRep)+' - '+buyerRepCity)
    run.bold = True

    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('AND')
    run.bold = True

    #source
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run( sellerName+' - '+sellerCity)
    run.bold = True

    #rep source
    if (str(sellerRep) != str(np.nan) and (str(sellerRep) != 'NAN')):
    #     print(np.nan, sellerRep)
        paragraph = document.add_paragraph()
        par_format = paragraph.paragraph_format
        par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
        run1= paragraph.add_run('Represented by: ')
#         run1.bold = True
        run= paragraph.add_run(str(sellerRep)+' - '+str(sellerRepCity))
        run.bold = True


    #THIS PURCHASE AND SALE AGREEMENT is entered into this 8TH day of December 2018, by and between 
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run= paragraph.add_run('THIS PURCHASE AND SALE AGREEMENT is entered into this '+adate+', by and between ')

    run1= paragraph.add_run(str(buyerName)+' - '+buyerCity+ ' ')
    run1.bold = True

    run2= paragraph.add_run('Represented by: ')

    run3= paragraph.add_run(str(buyerRep)+' - '+buyerRepCity+ ' ')
    run3.bold = True

    run4= paragraph.add_run('(hereinafter referred as "Buyer") with office address at the United Arab Emirates and ')

    run5= paragraph.add_run(sellerName+' - '+sellerCity)
    run5.bold = True

    if (str(sellerRep) != str(np.nan) and (str(sellerRep) != 'NAN')):
        run6= paragraph.add_run(' Represented by: ')

        run7= paragraph.add_run(str(sellerRep)+' - '+str(sellerRepCity))
        run7.bold = True
    run4= paragraph.add_run(' (hereinafter referred as "Seller”) with office address at the United Arab Emirates. ')

    #RECITALS:
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('RECITALS:')
    run.bold = True

    #WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY and
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA represented 
    #BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E can enter into this Sale and Purchase Agreement
    #and sign pertinent documents with full rights under terms and conditions specified therein;
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('WHEREAS')
    run0.bold = True

    run1= paragraph.add_run(', the ')

    run4= paragraph.add_run(sellerName+' - '+sellerCity )
    run4.bold = True

    if (str(sellerRep) != str(np.nan) and (str(sellerRep) != 'NAN')):
        run2= paragraph.add_run(' Represented by: ')

        run3= paragraph.add_run(str(sellerRep)+' - '+str(sellerRepCity) )
        run3.bold = True

    run6= paragraph.add_run(' and ' + str(buyerName)+' - '+buyerCity+ ' ')
    run6.bold = True

    run7= paragraph.add_run('Represented by: ')

    run8= paragraph.add_run(str(buyerRep)+' - '+buyerRepCity+ ' ')
    run8.bold = True

    run7= paragraph.add_run(' can enter into this Sale and Purchase Agreement and sign pertinent documents with full ' +
                            'rights under terms and conditions specified therein;')
    font = run7.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY desires to sell the Products
    #defined below and the SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA desires
    #to purchase the Products from SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY.
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('WHEREAS')
    run0.bold = True

    run1= paragraph.add_run(', the ')

    run2= paragraph.add_run(sellerName+' - '+sellerCity )
    run2.bold = True

    run3= paragraph.add_run(' desires to sell the Products defined below and the ')

    run4= paragraph.add_run(str(buyerName)+' - '+buyerCity+ ' ')
    run4.bold = True

    run5= paragraph.add_run(' desires to purchase the Products from ')

    run6= paragraph.add_run(sellerName+' - '+sellerCity + '. ')
    run6.bold = True
    font = run6.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #NOW THEREFORE, in consideration of the mutual covenants and the agreements herein contained and other
    #goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows:
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('NOW THEREFORE')
    run0.bold = True

    run1= paragraph.add_run(', in consideration of the mutual covenants and the agreements herein contained and other '
    + 'goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows: ')
    font = run1.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #Sale of Product.  SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY hereby sells to
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA and 
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA hereby purchases from
    # SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY the product details below:
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Sale of Product.')
    run0.bold = True
    run0.underline = True

    run1 = paragraph.add_run(' ' +sellerName+' - '+sellerCity)
    run1.bold = True

    run2= paragraph.add_run(' hereby sells to ' )

    run4= paragraph.add_run(str(buyerName)+' - '+buyerCity+ ' ')
    run4.bold = True

    run5= paragraph.add_run(' and ' )

    run6= paragraph.add_run(str(buyerName)+' - '+buyerCity+ ' ')
    run6.bold = True

    run7= paragraph.add_run(' hereby purchases from ' )

    run8= paragraph.add_run( sellerName+' - '+sellerCity )
    run8.bold = True

    run9= paragraph.add_run(' the product details below: ' )

    # p = document.add_paragraph('A plain paragraph having some ')
    # p.add_run('bold').bold = True
    # p.add_run(' and some ')
    # p.add_run('italic.').italic = True
    records = []
    rec = []
    for i in range(len(pname)):
        rec.append(i+1)
        rec.append(pname[i])
        rec.append(pqty[i])
        rec.append(punit[i])
        rec.append(punitp[i])
        rec.append(ptotal[i])
        records.append(rec)
        rec = []

    # document.styles['OR']
    table = document.add_table(rows=1, cols=6, style='Table Grid')
    hdr_cells = table.rows[0].cells
    hdr_cells[0].text = 'SR. NO.'
    hdr_cells[1].text = 'DESCRIPTION'
    hdr_cells[2].text = 'QTY'
    hdr_cells[3].text = 'UNIT OF MEASUREMENT'
    hdr_cells[4].text = 'UNIT PRICE'
    hdr_cells[5].text = 'AMOUNT'
    for cell in table.rows[0].cells:
        paragraphs = cell.paragraphs
        for paragraph in paragraphs:
            for run in paragraph.runs:
                run.bold = True
    c = 0
    for SR, DESCRIPTION, qty, UNITOFM, UNITPRICE, AMOUNT in records:
        qty = str(int(qty))
        if c ==1:
            paragraph = document.add_paragraph('\n \n \n \n')
#             table = document.add_table(rows=1, cols=6, style='Table Grid')
#             hdr_cells = table.rows[0].cells
#             hdr_cells[0].text = 'SR. NO.'
#             hdr_cells[1].text = 'DESCRIPTION'
#             hdr_cells[2].text = 'QTY'
#             hdr_cells[3].text = 'UNIT OF MEASUREMENT'
#             hdr_cells[4].text = 'UNIT PRICE'
#             hdr_cells[5].text = 'AMOUNT'

        c += 1 
        row_cells = table.add_row().cells
        row_cells[0].text = str(SR)
        row_cells[1].text = DESCRIPTION
        row_cells[2].text = str(UNITOFM)
        row_cells[3].text = qty
        row_cells[4].text = str(currency + '   ' + UNITPRICE)
        row_cells[5].text = str(currency + '   ' + str(AMOUNT))
    z = 0
    for row in table.rows:
        g = 0
        for cell in row.cells:
           
            paragraphs = cell.paragraphs
            
            for paragraph in paragraphs:
                
                par_format = paragraph.paragraph_format
                par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER  
                if (g == 1) and (z>0):
                    par_format.alignment = WD_ALIGN_PARAGRAPH.LEFT
                
                for run in paragraph.runs:
                    font = run.font
                    font.name = 'Arial Narrow'
                    font.size= Pt(10)
                    font.color.rgb = RGBColor(0x0, 0x0, 0x0)
            g +=1
        z += 1
    
    if len(records) == 1:
        paragraph = document.add_paragraph('\n \n \n')

    #2. Purchase Price.   SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA shall pay
    #to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY for the Products and for all obligations
    #specified herein, as full and complete consideration therefore, the sum of €      88,474.00 
    #(EIGHTY EIGHT THOUSAND FOUR HUNDRED SEVENTY FOUR EUROS ONLY).
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Purchase Price.')
    run0.bold = True
    run0.underline = True

    run1 = paragraph.add_run(' ' + str(buyerName)+' - '+buyerCity+ ' ')
    run1.bold = True

    run2= paragraph.add_run('shall pay to ' )

    run4= paragraph.add_run( sellerName+' - '+sellerCity )
    run4.bold = True

    run5= paragraph.add_run(' for the Products and for all obligations specified herein, as full ' + 
                            'and complete consideration therefore, the sum of ' )

    run6= paragraph.add_run(currency + ' ' + str(totamount))
    run6.bold = True

    run7= paragraph.add_run(' (' + amountToWord + ').')


    #3.Payment.  Payment of the Purchase Price shall be made by 
    #SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA or its representative 
    #BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY 
    #in full payment in advance before the delivery date.
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Payment.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' Payment of the Purchase Price shall be made by ' )

    run2= paragraph.add_run( str(buyerName)+' - '+buyerCity )
    run2.bold = True

    run3= paragraph.add_run(' or its representative ')
    run3.bold = False

    run4= paragraph.add_run( str(buyerRep)+' - '+buyerRepCity )
    run4.bold = True

    run5= paragraph.add_run(' to ')

    run6= paragraph.add_run( sellerName+' - '+sellerCity )
    run6.bold = True

    if (str(sellerRep) != str(np.nan) and (str(sellerRep) != 'NAN')):
        run7= paragraph.add_run(' or its representative  ' )
        run8= paragraph.add_run(str(sellerRep)+' - '+str(sellerRepCity))
        run8.bold = True
    run9= paragraph.add_run(' in full payment in advance before the delivery date.')


    #Acceptance.   “Acceptance" of the Product shall be deemed to occur on the date when, in the reasonable
    #opinion of SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA the Product conforms 
    #to the Specifications, and has continuously operated in compliance with the Specifications for thirty (30) 
    #days after Product Turnover
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Acceptance.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' “Acceptance" of the Product shall be deemed to occur on the date when, '+
                            'in the reasonable opinion of ' )

    run2= paragraph.add_run(str(buyerName)+' - '+buyerCity)
    run2.bold = True

    run4= paragraph.add_run(' the Product conforms to the Specifications, and has continuously operated in compliance ' + 
                            'with the Specifications for thirty (30) days after Product Turnover.' )

    #Indemnification. In the event either party breaches or is deemed to have breached any of the 
    #representations and warranties contained in this Agreement, or fails to perform or comply with any
    #of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and
    #defend the other party, and its directors, officers, shareholders, attorneys, representatives and
    #agents, from and against any damages incurred by the non-defaulting party. 
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Indemnification.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' In the event either party breaches or is deemed to have breached any of the '+
    'representations and warranties contained in this Agreement, or fails to perform or comply with any'+
    ' of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and'+
    ' defend the other party, and its directors, officers, shareholders, attorneys, representatives and'+
    ' agents, from and against any damages incurred by the non-defaulting party.')


    #General. SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY shall perform this Agreement
    #in compliance with all applicable local laws, rules, regulations, and ordinances, and represents that
    #it shall have obtained all licenses and permits required by law to engage in the activities necessary
    #to perform its obligations under this Agreement.  
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('General.')
    run0.bold = True
    run0.underline = True

    run2 = paragraph.add_run(' ' + sellerName+' - '+sellerCity + ' ')
    run2.bold = True

    run1= paragraph.add_run('shall perform this Agreement in compliance with all applicable local laws'+
                            ', rules, regulations, and ordinances, and represents that it shall have ' + 
                            'obtained all licenses and permits required by law to engage in the activities ' +
                            'necessary to perform its obligations under this Agreement. ' )
    s = ''
    for i in range(7-len(records)):
        s += '\n'
    paragraph = document.add_paragraph(s)
    paragraph = document.add_paragraph(int(1.33 * len(sellerName+' - '+sellerCity))*'_' + '\n')
    run0= paragraph.add_run(sellerName+' - '+sellerCity)
    run0.bold = True

    # document.add_picture('sign.png', width=Inches(2))
    paragraph = document.add_paragraph('\n \n \n \n')
    paragraph = document.add_paragraph(int(1.33 * len(str(buyerName)+' - '+buyerCity)) * '_'+'\n')
    run0= paragraph.add_run(str(buyerName)+' - '+buyerCity)
    run0.bold = True

    document.save('output/' + str(ref) + '.docx')

# %%
def changeCurrency(currency, amount):
#     print(str(track.loc[i,'currency']).lower())
    if str(currency).lower() == 'usd':
        return amount
    if str(currency).lower() == 'euro':

        return float(amount * 1.13)
    elif str(currency).lower()[:] == 'aed':

        return float(amount * 0.27)
    elif str(currency).lower() == 'pound':

        return float(amount * 1.32)
    elif str(currency).lower() == 'cad':

        return float(amount * 0.75)
    else:

        return "Fatal Error in Changing Currency"

# %%
#PO tracking sheet
vect = []
for co in range(len(track['REF'])):
    vector = list(track.loc[co])
    sellerRep = str(vector[1]).upper()
    sellerRepCity = vector[2]
    try:
        sellerRepCity = sellerRepCity.replace('-',',')
    except:
        1+1
    try:
        sellerRepCity = sellerRepCity.lower()
        sellerRepCity = sellerRepCity.replace('uae','U.A.E')
        sellerRepCity = sellerRepCity.upper()
    except:
        1+1

    sellerName = str(vector[3]).upper()
    sellerCity = vector[4]
    try:
        sellerCity = sellerCity.replace('-',',')
    except:
        1+1
    try:
        sellerCity = sellerCity.lower()
        sellerCity = sellerCity.replace('uae','U.A.E')
        sellerCity = sellerCity.upper()
    except:
        1+1

    buyerName = str(vector[5]).upper()
    buyerCity = vector[6]
    try:
        buyerCity = buyerCity.replace('-',',')
    except:
        1+1
    try:
        buyerCity = buyerCity.lower()
        buyerCity = buyerCity.replace('uae','U.A.E')
        buyerCity = buyerCity.upper()
    except:
        1+1
    buyerRep = str(vector[7]).upper()
    buyerRepCity = vector[8]
    try:
        buyerRepCity = buyerRepCity.replace('-',',')
    except:
        1+1
    try:
        buyerRepCity = buyerRepCity.lower()
        buyerRepCity = buyerRepCity.replace('uae','U.A.E')
        buyerRepCity = buyerRepCity.upper()
    except:
        1+1
    try:
        fdate = vector[48]
    except:
        fdate = vector[41]
#     print(fdate)
    adate = ''
    for ch in fdate:
        if ch !=' ':
            adate = adate + ch
        else:
            try:
                adate = adate + ordinal(int(adate)) + ' day of '
            except:
                adate = adate + ' '
    product = vector[14:39]
    product
    pname = []
    pqty = []
    punit = []
    punitp = []
    ptotal = []
    cur = []
    for i in range(5):
        if not str(product[i*5]) == str(np.nan):
            pname.append(product[i*5])
            pqty.append(product[i*5 +1])
            punit.append(product[i*5+2])
            punitp.append(amontformat(str(product[i*5+3])))
            ptotal.append(amontformat(str(product[i*5+4])))
    currency = vector[40]
    amount = vector[12]
    #money format
    totamount = amontformat(str(float(amount)))
#     print(totamount)
    amountToWord = vector[13]
    usdamount = changeCurrency(currency, amount)
    if(float(usdamount) >= 54450.00):
        produceDocxFile(co, track.loc[co, 'REF'])
