# %%
from docx import Document
from docx.shared import Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Pt
import pandas as pd
# from docx.enum.dml import MSO_THEME_COLOR
from docx.shared import RGBColor
import numpy as np

# from docx.enum.style import WD_STYLE_TYPE

# %%
track = pd.read_csv('Tracking Sheet output.csv')
track
# Out:
#           REF                                        repExporter  \
# 0      SB1429  A T S HEAVY EQUIPMENT AND MACHINERY SPARE PART...
# 1      SB1430                            ANA GENERAL TRADING LLC
# 2      SB1463                               APEX TECHNOLOGY FZCO
# 3      SB1447                                AVRASYA TRADING FZE
# 4      SB1416                            BEAUTY SKY SERVICES LLC
# 5      SB1453                  BEYZADE PETRA OLIUM EQUIPMENT FZE
# 6      SB1454                         C STAR GENERAL TRADING LLC
# 7      SB1415                                   CHEMI TECHNO FZE
# 8      SB1475                                   CHEMI TECHNO FZE
# 9      SB1469                                      CIS PETRO LLC
# 10     SB1405                          DELTACHEM MIDDLE EAST LLC
# 11     SB1455                        DIAGRAM GENERAL TRADING LLC
# 12     SB1464                               ENDEAVOR TRADING FZE
# 13     SB1470  FIVE STARS ELECTRICAL AND MECHANICAL EQUIPMENT...
# 14     SB1443                                  FNSA FUEL LTD FZC
# 15     SB1406                      GERMAN COMMODITY TRADING DMCC
# 16     SB1423        GOLDEN TRUST BUILDING MATERIALS TRADING LLC
# 17     SB1461                   GULF TURBO REPAIR & SERVICES FZC
# 18     SB1476                     INTERTRADE GENERAL TRADING LLC
# 19     SB1444                                      KONG STAR FZE
# 20     SB1457                    LIFE PHARMA GENERAL TRADING LLC
# 21     SB1400  LIGHT SHINE MIDDLE EAST SAFETY EQUIPMENT TRADI...
# 22     SB1458                     MAPLE LEAF GENERAL TRADING LLC
# 23     SB1465                                       METACHEM FZE
# 24     SB1472                         METROMAC MARINE AUTOMATION
# 25     SB1417                        MYRILGULF INTERNATIONAL FZE
# 26     SB1411                        NOBLEFU GENERAL TRADING LLC
# 27     SB1420                                    ONTRACKING FZCO
# 28     SB1431                                 OROPAY TRADING LLC
# 29     SB1412                      ORTA ASIA GENERAL TRADING FZE
# ..        ...                                                ...
# 43     SB1473                                   WORLD MARINE FZE
# 44     SB1480                                                NaN
# 45     SB1488                                                NaN
# 46     SB1485                                  BEHTA TRADING FZE
# 47     SB1492                                                NaN
# 48     SB1482                                                NaN
# 49     SB1483                                                NaN
# 50     SB1486                                                NaN
# 51     SB1481                                                NaN
# 52     SB1493                                                NaN
# 53     SB1484                                                NaN
# 54     SB1487                                                NaN
# 55     SB1494                                                NaN
# 56  SB1479-CL                            PECUNION CHEMICALS DMCC
# 57  SB1491-CL                                                NaN
# 58  SB1452-CL                               ZK TECO SECURITY LLC
# 59  SB1404-CL                    TAICHI HOLDINGS MIDDLE EAST FZE
# 60  SB1467-CL                     SYED NAEEM GENERAL TRADING LLC
# 61  SB1441-CL                               SBC COOPERATION DMCC
# 62  SB1451-CL              RHV INTERNATIONAL GENERAL TRADING FZE
# 63  SB1448-CL                        NOBLEFU GENERAL TRADING LLC
# 64  SB1425-CL  NIOLIT INDUSTRIAL EQUIPMENT AND SPARE PARTS TR...
# 65  SB1445-CL                                        NIA LIMITED
# 66  SB1474-CL                          J.O (M.E) ENGINEERING LLC
# 67  SB1471-CL                                                NaN
# 68  SB1419-CL                     HAPPY MINT GENERAL TRADING LLC
# 69  SB1422-CL                                                NaN
# 70  SB1397-CL            GOLDEN TRUST BUILDING MATERIALS TRADING
# 71  SB1438-CL                                                NaN
# 72  SB1460-CL             ASAD HUSSAIN ALI KIKHA GENERAL TRADING
#
#                        cityOfRepExporter  \
# 0                             Dubai- UAE
# 1            DUBAI- UNITED ARAB EMIRATES
# 2                             Dubai- UAE
# 3                             Dubai- UAE
# 4                             Dubai- UAE
# 5                             Dubai- UAE
# 6                             Dubai- UAE
# 7                             Dubai- UAE
# 8                             Dubai- UAE
# 9                             Dubai- UAE
# 10                            Dubai- UAE
# 11                            Dubai- UAE
# 12                            Ajman- UAE
# 13                          Sharjah- UAE
# 14                         Fujairah- UAE
# 15                            Dubai- UAE
# 16                            Dubai- UAE
# 17                            Dubai- UAE
# 18                            Dubai- UAE
# 19                            Dubai- UAE
# 20                            Dubai- UAE
# 21                            Dubai- UAE
# 22                            Dubai- UAE
# 23                            Ajman- UAE
# 24                            Dubai- UAE
# 25                            Ajman- UAE
# 26                            Dubai- UAE
# 27                            Dubai- UAE
# 28                            Dubai- UAE
# 29  RAS AL KHAIMAH- UNITED ARAB EMIRATES
# ..                                   ...
# 43                            Dubai- UAE
# 44                                   NaN
# 45                                   NaN
# 46                          Sharjah- UAE
# 47                                   NaN
# 48                                   NaN
# 49                                   NaN
# 50                                   NaN
# 51                                   NaN
# 52                                   NaN
# 53                                   NaN
# 54                                   NaN
# 55                                   NaN
# 56                            Dubai- UAE
# 57                                   NaN
# 58                            Dubai- UAE
# 59                            Dubai- UAE
# 60                            Dubai- UAE
# 61                            Dubai- UAE
# 62                            Dubai- UAE
# 63                            Dubai- UAE
# 64                            Dubai- UAE
# 65                            Dubai- UAE
# 66                            Dubai- UAE
# 67                                   NaN
# 68                            Dubai- UAE
# 69                                   NaN
# 70                            Dubai- UAE
# 71                                   NaN
# 72                            Dubai- UAE
#
#                                              exporter       cityOfExporter  \
# 0                           SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 1         SZ KETA TECHNOLOGY CO LTD - GUANDONG- CHINA      GUANDONG- CHINA
# 2                           SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 3                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 4                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 5                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 6                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 7                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 8                           SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 9                      ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 10                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 11                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 12                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 13                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 14                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 15                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 16                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 17                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 18                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 19                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 20                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 21                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 22                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 23                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 24                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 25                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 26                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 27                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 28                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 29  ANADOLU EFES BIRACILIK VE MALT SANAYII AS - IS...     Istanbul- Turkey
# ..                                                ...                  ...
# 43                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 44          A.C INTERNATIONAL TRADING COMPANY LIMITED     Hong Kong- China
# 45                                     AGT ITALIA SAS    Bergamo BG- Italy
# 46                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 47         DURKO اEVRE ENERJI TEKNIGI VE TICARET A.S.     Istanbul- Turkey
# 48                                          EPOKA A/S   Svenstrup- Denmark
# 49                                          EPOKA A/S   Svenstrup- Denmark
# 50                                    ISHA FOUNDATION    Tamil Nadu- India
# 51                                     LOVATO GAS SPA       Vicenza- Italy
# 52                                          ROBEMA NV     Antwerp- Belgium
# 53                                   SIVANTOS PTE LTD            Singapore
# 54                                   SIVANTOS PTE LTD            Singapore
# 55                                  TBIO CROP SCIENCE         Xi An- China
# 56                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 57         APPLIED INNOVATION MANAGEMENT IN SWEDEN AB    Stockholm- Sweden
# 58                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 59                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 60                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 61                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 62                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 63                     Refarmed Chemicals Switzerland  Lugano- Switzerland
# 64                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 65                     ACT SINO INTERNATIONAL LIMITED     Hong Kong- China
# 66                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 67                        HYK TRADING ENTERPRISES LTD     Labuan- Malaysia
# 68                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 69            GOLDEN TRUST BUILDING MATERIALS TRADING     Labuan- Malaysia
# 70                          SUD-CHEMIE INDIA PVT. LTD       Gujarat- India
# 71                    GOLDEN LEAF GENERAL TRADING LLC     Labuan- Malaysia
# 72                     Refarmed Chemicals Switzerland  Lugano- Switzerland
#
#                            importer cityOfImporter  \
# 0   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 1   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 2   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 3   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 4   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 5   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 6   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 7   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 8   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 9   STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 10  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 11  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 12  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 13  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 14  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 15  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 16  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 17  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 18  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 19  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 20  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 21  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 22  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 23  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 24  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 25  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 26  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 27  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 28  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 29  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# ..                              ...            ...
# 43  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 44  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 45  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 46  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 47  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 48  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 49  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 50  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 51  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 52  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 53  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 54  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 55  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 56  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 57  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 58  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 59  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 60  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 61  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 62  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 63  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 64  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 65  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 66  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 67  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 68  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 69  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 70  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 71  STIRLING BRIDGE GENERAL TRADING  Haikou- China
# 72  STIRLING BRIDGE GENERAL TRADING  Haikou- China
#
#                                 repImporter cityOfrepImporter  \
# 0   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 1   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 2   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 3   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 4   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 5   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 6   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 7   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 8   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 9   STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 10  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 11  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 12  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 13  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 14  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 15  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 16  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 17  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 18  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 19  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 20  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 21  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 22  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 23  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 24  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 25  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 26  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 27  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 28  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 29  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# ..                                      ...               ...
# 43  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 44  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 45  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 46  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 47  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 48  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 49  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 50  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 51  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 52  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 53  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 54  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 55  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 56  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 57  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 58  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 59  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 60  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 61  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 62  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 63  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 64  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 65  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 66  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 67  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 68  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 69  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 70  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 71  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
# 72  STIRLING BRIDGE CHEMICALS TRADING L.L.C        Dubai- UAE
#
#                   Origin     ...      p4unitp p4total  p5name p5qty p5unit  \
# 0         Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 1         Origin:  CHINA     ...          NaN     NaN     NaN   NaN    NaN
# 2         Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 3         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 4         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 5         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 6         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 7         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 8         Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 9         Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 10        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 11        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 12  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 13  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 14        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 15  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 16  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 17        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 18  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 19  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 20  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 21  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 22  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 23        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 24        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 25        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 26  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 27        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 28  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 29       Origin:  Turkey     ...          NaN     NaN     NaN   NaN    NaN
# ..                   ...     ...          ...     ...     ...   ...    ...
# 43  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 44        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 45        Origin:  Italy     ...          NaN     NaN     NaN   NaN    NaN
# 46        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 47       Origin:  Turkey     ...          NaN     NaN     NaN   NaN    NaN
# 48      Origin:  Denmark     ...          NaN     NaN     NaN   NaN    NaN
# 49      Origin:  Denmark     ...          NaN     NaN     NaN   NaN    NaN
# 50        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 51        Origin:  Italy     ...          NaN     NaN     NaN   NaN    NaN
# 52      Origin:  Belgium     ...          NaN     NaN     NaN   NaN    NaN
# 53     Origin: Singapore     ...          NaN     NaN     NaN   NaN    NaN
# 54     Origin: Singapore     ...          NaN     NaN     NaN   NaN    NaN
# 55        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 56        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 57       Origin:  Sweden     ...          NaN     NaN     NaN   NaN    NaN
# 58        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 59  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 60        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 61        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 62        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 63  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
# 64        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 65        Origin:  China     ...          NaN     NaN     NaN   NaN    NaN
# 66        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 67     Origin:  Malaysia     ...          NaN     NaN     NaN   NaN    NaN
# 68        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 69     Origin:  Malaysia     ...          NaN     NaN     NaN   NaN    NaN
# 70        Origin:  India     ...          NaN     NaN     NaN   NaN    NaN
# 71     Origin:  Malaysia     ...          NaN     NaN     NaN   NaN    NaN
# 72  Origin:  Switzerland     ...          NaN     NaN     NaN   NaN    NaN
#
#     p5unitp p5total  numOfClient  currency         date
# 0       NaN     NaN          NaN       AED  18-Dec-2018
# 1       NaN     NaN         18.1       AED  18-Dec-2018
# 2       NaN     NaN          NaN       AED  28-Dec-2018
# 3       NaN     NaN          NaN       AED  24-Dec-2018
# 4       NaN     NaN          NaN       AED  10-Dec-2018
# 5       NaN     NaN          NaN       AED  25-Dec-2018
# 6       NaN     NaN          NaN       AED  25-Dec-2018
# 7       NaN     NaN          NaN       AED   9-Dec-2018
# 8       NaN     NaN          NaN       AED   1-Jan-2019
# 9       NaN     NaN          NaN       AED  29-Dec-2018
# 10      NaN     NaN          NaN       AED   8-Dec-2018
# 11      NaN     NaN          NaN       AED  25-Dec-2018
# 12      NaN     NaN          NaN       AED  28-Dec-2018
# 13      NaN     NaN          NaN       AED  29-Dec-2018
# 14      NaN     NaN          NaN       AED  22-Dec-2018
# 15      NaN     NaN          NaN       AED   8-Dec-2018
# 16      NaN     NaN          NaN       AED  17-Dec-2018
# 17      NaN     NaN          NaN       AED  27-Dec-2018
# 18      NaN     NaN          NaN       AED   1-Jan-2019
# 19      NaN     NaN          NaN       AED  23-Dec-2018
# 20      NaN     NaN          NaN       AED  25-Dec-2018
# 21      NaN     NaN          NaN       AED   6-Dec-2018
# 22      NaN     NaN          NaN       AED  25-Dec-2018
# 23      NaN     NaN          NaN       AED  28-Dec-2018
# 24      NaN     NaN          NaN       AED  30-Dec-2018
# 25      NaN     NaN          NaN       AED  10-Dec-2018
# 26      NaN     NaN          NaN       AED   8-Dec-2018
# 27      NaN     NaN          NaN       AED  13-Dec-2018
# 28      NaN     NaN          NaN       AED  18-Dec-2018
# 29      NaN     NaN         15.8       AED   8-Dec-2018
# ..      ...     ...          ...       ...          ...
# 43      NaN     NaN          NaN       AED  30-Dec-2018
# 44      NaN     NaN          NaN      EURO  21-Dec-2018
# 45      NaN     NaN          NaN      EURO  28-Dec-2018
# 46      NaN     NaN          NaN      EURO  27-Dec-2018
# 47      NaN     NaN          NaN      EURO  28-Dec-2018
# 48      NaN     NaN          NaN      EURO  23-Dec-2018
# 49      NaN     NaN          NaN      EURO  23-Dec-2018
# 50      NaN     NaN          NaN      EURO  27-Dec-2018
# 51      NaN     NaN          NaN      EURO  21-Dec-2018
# 52      NaN     NaN          NaN      EURO  28-Dec-2018
# 53      NaN     NaN          NaN      EURO  23-Dec-2018
# 54      NaN     NaN          NaN      EURO  27-Dec-2018
# 55      NaN     NaN          NaN      EURO  28-Dec-2018
# 56      NaN     NaN          NaN      EURO   8-Dec-2018
# 57      NaN     NaN          NaN      EURO  28-Dec-2018
# 58      NaN     NaN          NaN       AED  18-Dec-2018
# 59      NaN     NaN          NaN       AED   7-Dec-2018
# 60      NaN     NaN          NaN       AED  28-Dec-2018
# 61      NaN     NaN          NaN       AED  17-Dec-2018
# 62      NaN     NaN          NaN       AED  24-Dec-2018
# 63      NaN     NaN          NaN       AED  20-Dec-2018
# 64      NaN     NaN          NaN       AED   4-Dec-2018
# 65      NaN     NaN          NaN       AED   8-Dec-2018
# 66      NaN     NaN          NaN       AED  27-Dec-2018
# 67      NaN     NaN          NaN       AED  25-Dec-2018
# 68      NaN     NaN          NaN       AED  13-Dec-2018
# 69      NaN     NaN          NaN       AED   8-Dec-2018
# 70      NaN     NaN          NaN       AED   4-Dec-2018
# 71      NaN     NaN          NaN       AED  20-Dec-2018
# 72      NaN     NaN          NaN       AED  27-Dec-2018
#
# [73 rows x 42 columns]

# %%
client = pd.read_csv('2018 ABACUS CLIENTS.csv')
client.plot()

# %%
def lcs(X , Y): 
    # find the length of the strings 
    m = len(X) 
    n = len(Y) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n+1) for i in range(m+1)] 
  
    """Following steps build L[m+1][n+1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n] 
#end of function lcs

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    for char in clientlist.loc[c,'LIST OF COMPANY']:
        if char != '.':
            num = num + char
        else:
            break
    return num
    
def bestmatch(candid,clientlist):
    # Remove all bad charachters.
    candid = ''.join(e for e in candid if e.isalnum())
    c = 0
    maxAl = 0
    candidRow = []
    num = ''
    maxLCStoClient = 0
    for client in clientlist['LIST OF COMPANY']:
    #     print(client)
        candidLcs = lcs(candid.lower(), client.lower())
        LCStoClient = candidLcs / len(client)
#         print(candidLcs)
#         print(len(candid),candidLcs)
#         if candidLcs > maxAl:
#             match = c
#             maxAl = candidLcs
#             maxLCStoClient = LCStoClient
#         elif (candidLcs == maxAl) and (maxLCStoClient < LCStoClient):
#             match = c
#             maxAl = candidLcs
#             maxLCStoClient = LCStoClient                
                
#         print(len(candid),candidLcs)
        if (candidLcs == len(candid)):
            if (maxLCStoClient < LCStoClient):
                candidRow = list(clientlist.iloc[c])
                num = getClientRef(c, clientlist)
                maxLCStoClient = LCStoClient
#                 print(maxLCStoClient)
        c+=1


    return num, candidRow
# bestmatch('ANA GENERAL TRADING LLC',client)

# %%
#Finding major company of REP.
def majorCoOfREP(candid,client):
    bestmatch(candid,client)
    
    return ''

# %%
def ordinal(date):
    if date == 1:
        ordin = 'ST'
    elif date == 2:
        ordin = 'ND'
    elif date == 3:
        ordin = 'RD'
    else:
        ordin = 'TH'
    return ordin

# %%
#PO tracking sheet
vector = list(track.loc[0])
sellerRep = vector[1]
sellerRepCity = vector[2]
try:
    sellerRepCity = sellerRepCity.replace('-',',')
except:
    1+1
try:
    sellerRepCity = sellerRepCity.lower()
    sellerRepCity = sellerRepCity.replace('uae','U.A.E')
    sellerRepCity = sellerRepCity.upper()
except:
    1+1

sellerName = vector[3]
sellerCity = vector[4]
try:
    sellerCity = sellerCity.replace('-',',')
except:
    1+1
try:
    sellerCity = sellerCity.lower()
    sellerCity = sellerCity.replace('uae','U.A.E')
    sellerCity = sellerCity.upper()
except:
    1+1

buyerName = vector[5]
buyerCity = vector[6]
try:
    buyerCity = buyerCity.replace('-',',')
except:
    1+1
try:
    buyerCity = buyerCity.lower()
    buyerCity = buyerCity.replace('uae','U.A.E')
    buyerCity = buyerCity.upper()
except:
    1+1

buyerRep = vector[7]
buyerRepCity = vector[8]
try:
    buyerRepCity = buyerRepCity.replace('-',',')
except:
    1+1
try:
    buyerRepCity = buyerRepCity.lower()
    buyerRepCity = buyerRepCity.replace('uae','U.A.E')
    buyerRepCity = buyerRepCity.upper()
except:
    1+1

fdate = vector[41]
adate = ''
for ch in fdate:
    if ch !='-':
        adate = adate + ch
    else:
        try:
            adate = adate + ordinal(int(adate)) + ' day of '
        except:
            adate = adate + ' '

product = vector[14:39]
product
pname = []
pqty = []
punit = []
punitp = []
ptotal = []

for i in range(5):
    if not str(product[i*5]) == str(np.nan):
        pname.append(product[i*5])
        pqty.append(product[i*5 +1])
        punit.append(product[i*5+2])
        punitp.append(product[i*5+3])
        ptotal.append(product[i*5+4])

currency = vector[40]

totamount = vector[12]
amountToWord = vector[13]

# %%
#Title
document =  Document('spa1.docx')
paragraph = document.add_paragraph('\n \n \n \n \n')
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run('PURCHASE AND SALE AGREEMENT')
run.bold = True
font = run.font
font.name = 'Arial'
font.size = Pt(14)
font.color.rgb = RGBColor(0x0, 0x0, 0x0)

style = document.styles['Normal']
font = style.font
font.name = 'Nirmala UI'
font.size = Pt(9)
font.color.rgb = RGBColor(0x0, 0x0, 0x0)

paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run('BY AND BETWEEN')
run.bold = True

#buyer
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run(str(buyerName)+', '+buyerCity)
run.bold = True

#repBuyer
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run1= paragraph.add_run('Represented by: ')

run= paragraph.add_run(str(buyerRep)+', '+buyerRepCity)
run.bold = True

paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run('AND')
run.bold = True

#source
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run( sellerName+', '+sellerCity)
run.bold = True

#rep source
if (str(sellerRep) != str(np.nan)):
#     print(np.nan, sellerRep)
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run1= paragraph.add_run('Represented by: ')
    run1.bold = True
    run= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
    run.bold = True


#THIS PURCHASE AND SALE AGREEMENT is entered into this 8TH day of December 2018, by and between 
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.first_line_indent = Inches(0.27)
run= paragraph.add_run('THIS PURCHASE AND SALE AGREEMENT is entered into this '+adate+', by and between ')

run1= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
run1.bold = True

run2= paragraph.add_run('Represented by: ')

run3= paragraph.add_run(str(buyerRep)+', '+buyerRepCity+ ' ')
run3.bold = True

run4= paragraph.add_run('(hereinafter referred as "Buyer") with office address at the United Arab Emirates and ')

run5= paragraph.add_run(sellerName+', '+sellerCity)
run5.bold = True

if (str(sellerRep) != str(np.nan)):
    run6= paragraph.add_run(' Represented by: ')

    run7= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
    run7.bold = True
run4= paragraph.add_run(' (hereinafter referred as "Seller”) with office address at the United Arab Emirates. ')

#RECITALS:
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
run= paragraph.add_run('RECITALS:')
run.bold = True

#WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY and
# SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA represented 
#BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E can enter into this Sale and Purchase Agreement
#and sign pertinent documents with full rights under terms and conditions specified therein;
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.first_line_indent = Inches(0.27)
run0= paragraph.add_run('WHEREAS')
run0.bold = True

run1= paragraph.add_run(', the ')
    
run4= paragraph.add_run(sellerName+', '+sellerCity )
run4.bold = True

if (str(sellerRep) != str(np.nan)):
    run2= paragraph.add_run(' Represented by: ')

    run3= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity) + ' and ')
    run3.bold = True

run6= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
run6.bold = True

run7= paragraph.add_run('Represented by: ')

run8= paragraph.add_run(str(buyerRep)+', '+buyerRepCity+ ' ')
run8.bold = True

run7= paragraph.add_run(' can enter into this Sale and Purchase Agreement and sign pertinent documents with full ' +
                        'rights under terms and conditions specified therein;')
font = run7.font
font.name = 'Nirmala UI'
font.size = Pt(9)
font.color.rgb = RGBColor(0x0, 0x0, 0x0)

#WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY desires to sell the Products
#defined below and the SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA desires
#to purchase the Products from SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY.
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.first_line_indent = Inches(0.27)
run0= paragraph.add_run('WHEREAS')
run0.bold = True

run1= paragraph.add_run(', the ')

run2= paragraph.add_run(sellerName+', '+sellerCity )
run2.bold = True

run3= paragraph.add_run(' desires to sell the Products defined below and the ')

run4= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
run4.bold = True

run5= paragraph.add_run(' desires to purchase the Products from ')

run6= paragraph.add_run(sellerName+', '+sellerCity + '. ')
run6.bold = True
font = run6.font
font.name = 'Nirmala UI'
font.size = Pt(9)
font.color.rgb = RGBColor(0x0, 0x0, 0x0)

#NOW THEREFORE, in consideration of the mutual covenants and the agreements herein contained and other
#goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows:
paragraph = document.add_paragraph()
par_format = paragraph.paragraph_format
par_format.first_line_indent = Inches(0.27)
run0= paragraph.add_run('NOW THEREFORE')
run0.bold = True

run1= paragraph.add_run(', in consideration of the mutual covenants and the agreements herein contained and other '
+ 'goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows: ')
font = run1.font
font.name = 'Nirmala UI'
font.size = Pt(9)
font.color.rgb = RGBColor(0x0, 0x0, 0x0)

#Sale of Product.  SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY hereby sells to
# SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA and 
# SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA hereby purchases from
# SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY the product details below:
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('Sale of Product.')
run0.bold = True
run0.underline = True

run1 = paragraph.add_run(' ' +sellerName+', '+sellerCity)
run1.bold = True

run2= paragraph.add_run(' hereby sells to ' )

run4= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
run4.bold = True

run5= paragraph.add_run(' and ' )

run6= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
run6.bold = True

run7= paragraph.add_run(' hereby purchases from ' )

run8= paragraph.add_run( sellerName+', '+sellerCity )
run8.bold = True

run9= paragraph.add_run(' the product details below: ' )

# p = document.add_paragraph('A plain paragraph having some ')
# p.add_run('bold').bold = True
# p.add_run(' and some ')
# p.add_run('italic.').italic = True

records = []
rec = []
for i in range(len(pname)):
    rec.append(i+1)
    rec.append(pname[i])
    rec.append(pqty[i])
    rec.append(punit[i])
    rec.append(punitp[i])
    rec.append(ptotal[i])
    records.append(rec)
    rec = []
    
# document.styles['OR']
table = document.add_table(rows=1, cols=6, style='Table Grid')
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'SR. NO.'
hdr_cells[1].text = 'DESCRIPTION'
hdr_cells[2].text = 'UNIT OF MEASUREMENT'
hdr_cells[3].text = 'QTY'
hdr_cells[4].text = 'UNIT PRICE'
hdr_cells[5].text = 'AMOUNT'

c = 0
for SR, DESCRIPTION, UNITOFM, qty, UNITPRICE, AMOUNT in records:
    if c ==1:
        paragraph = document.add_paragraph('\n \n \n \n \n')
        table = document.add_table(rows=1, cols=6, style='Table Grid')
        hdr_cells = table.rows[0].cells
        hdr_cells[0].text = 'SR. NO.'
        hdr_cells[1].text = 'DESCRIPTION'
        hdr_cells[2].text = 'UNIT OF MEASUREMENT'
        hdr_cells[3].text = 'QTY'
        hdr_cells[4].text = 'UNIT PRICE'
        hdr_cells[5].text = 'AMOUNT'
        
    row_cells = table.add_row().cells
    row_cells[0].text = str(SR)
    row_cells[1].text = DESCRIPTION
    row_cells[2].text = str(UNITOFM)
    row_cells[3].text = qty
    row_cells[4].text = str(UNITPRICE)
    row_cells[5].text = str(AMOUNT)
for row in table.rows:
    for cell in row.cells:
        paragraphs = cell.paragraphs
        for paragraph in paragraphs:
            par_format = paragraph.paragraph_format
            par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER            
            for run in paragraph.runs:
                font = run.font
                font.name = 'Arial Narrow'
                font.size= Pt(10)
                font.color.rgb = RGBColor(0x0, 0x0, 0x0)
for cell in table.rows[0].cells:
    paragraphs = cell.paragraphs
    for paragraph in paragraphs:
        for run in paragraph.runs:
            run.bold = True
if len(records) == 1:
    paragraph = document.add_paragraph('\n \n \n \n \n \n')
#2. Purchase Price.   SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA shall pay
#to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY for the Products and for all obligations
#specified herein, as full and complete consideration therefore, the sum of €      88,474.00 
#(EIGHTY EIGHT THOUSAND FOUR HUNDRED SEVENTY FOUR EUROS ONLY).
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('Purchase Price.')
run0.bold = True
run0.underline = True

run1 = paragraph.add_run(' ' + str(buyerName)+', '+buyerCity+ ' ')
run1.bold = True

run2= paragraph.add_run('shall pay to ' )

run4= paragraph.add_run( sellerName+', '+sellerCity )
run4.bold = True

run5= paragraph.add_run(' for the Products and for all obligations specified herein, as full ' + 
                        'and complete consideration therefore, the sum of ' )

run6= paragraph.add_run(currency + ' ' + str(totamount))
run6.bold = True

run7= paragraph.add_run(' (' + amountToWord + ').')


#3.Payment.  Payment of the Purchase Price shall be made by 
#SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA or its representative 
#BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY 
#in full payment in advance before the delivery date.
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('Payment.')
run0.bold = True
run0.underline = True

run1= paragraph.add_run(' Payment of the Purchase Price shall be made by ' )

run2= paragraph.add_run( str(buyerName)+', '+buyerCity )
run2.bold = True

run3= paragraph.add_run(' or its representative ')
run3.bold = False

run4= paragraph.add_run( str(buyerRep)+', '+buyerRepCity )
run4.bold = True

run5= paragraph.add_run(' to ')

run6= paragraph.add_run( sellerName+', '+sellerCity )
run6.bold = True

if (str(sellerRep) != str(np.nan)):
    run7= paragraph.add_run(' or its representative  ' )
    run8= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
    run8.bold = True
run9= paragraph.add_run(' in full payment in advance before the delivery date.')


#Acceptance.   “Acceptance" of the Product shall be deemed to occur on the date when, in the reasonable
#opinion of SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA the Product conforms 
#to the Specifications, and has continuously operated in compliance with the Specifications for thirty (30) 
#days after Product Turnover
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('Acceptance.')
run0.bold = True
run0.underline = True

run1= paragraph.add_run(' “Acceptance" of the Product shall be deemed to occur on the date when, '+
                        'in the reasonable opinion of ' )

run2= paragraph.add_run(str(buyerName)+', '+buyerCity)
run2.bold = True
                        
run4= paragraph.add_run(' the Product conforms to the Specifications, and has continuously operated in compliance ' + 
                        'with the Specifications for thirty (30) days after Product Turnover.' )

#Indemnification. In the event either party breaches or is deemed to have breached any of the 
#representations and warranties contained in this Agreement, or fails to perform or comply with any
#of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and
#defend the other party, and its directors, officers, shareholders, attorneys, representatives and
#agents, from and against any damages incurred by the non-defaulting party. 
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('Indemnification.')
run0.bold = True
run0.underline = True
                                                
run1= paragraph.add_run(' In the event either party breaches or is deemed to have breached any of the '+
'representations and warranties contained in this Agreement, or fails to perform or comply with any'+
' of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and'+
' defend the other party, and its directors, officers, shareholders, attorneys, representatives and'+
' agents, from and against any damages incurred by the non-defaulting party.')


#General. SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY shall perform this Agreement
#in compliance with all applicable local laws, rules, regulations, and ordinances, and represents that
#it shall have obtained all licenses and permits required by law to engage in the activities necessary
#to perform its obligations under this Agreement.  
paragraph = document.add_paragraph()
styles = document.styles
paragraph.style = document.styles['List Paragraph']

par_format = paragraph.paragraph_format

run0= paragraph.add_run('General.')
run0.bold = True
run0.underline = True

run2 = paragraph.add_run(' ' + sellerName+', '+sellerCity + ' ')
run2.bold = True

run1= paragraph.add_run('shall perform this Agreement in compliance with all applicable local laws'+
                        ', rules, regulations, and ordinances, and represents that it shall have ' + 
                        'obtained all licenses and permits required by law to engage in the activities ' +
                        'necessary to perform its obligations under this Agreement. ' )
s = ''
for i in range(6-len(records)):
    s += '\n'
paragraph = document.add_paragraph(s)
paragraph = document.add_paragraph(int(1.33 * len(sellerName+', '+sellerCity))*'_' + '\n')
run0= paragraph.add_run(sellerName+', '+sellerCity)
run0.bold = True

document.add_picture('sign.png', width=Inches(2))

paragraph = document.add_paragraph(int(1.33 * len(str(buyerName)+', '+buyerCity)) * '_'+'\n')
run0= paragraph.add_run(str(buyerName)+', '+buyerCity)
run0.bold = True

document.save('demo.docx')

# %%
def getText(filename):
    doc = Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(' ' + para.text)
        if 'NOW THEREFORE' in para.text:
            para.text = 'wtf'
    return '\n\n'.join(fullText)

# %%
doc = Document('dem.docx')
fullText = []
for para in doc.paragraphs:
    fullText.append(' ' + para.text)
    if 'NOW THEREFORE' in para.text:
        para.text = 'wtf'
doc.save('dem.docx')
