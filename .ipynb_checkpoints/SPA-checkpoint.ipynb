# %%
from docx import Document
from docx.shared import Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH 
from docx.shared import Pt
import pandas as pd
from docx.shared import RGBColor
import numpy as np

# %%
track = pd.read_csv('Tracking Sheet output.csv',encoding='latin1')
track
# Out:
#             REF                                        repExporter  \
# 0      HLG-0689                                AL FEEL TRADING LLC
# 1      HLG-0754                                AL FEEL TRADING LLC
# 2      HLG-0690                      ALKHALSAN GENERAL TRADING LLC
# 3      HLG-0725                                                NaN
# 4      HLG-0756                          ANWAAR MEDICAL CENTER LLC
# 5      HLG-0746                                                NaN
# 6      HLG-0684           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 7      HLG-0713           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 8      HLG-0714           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 9      HLG-0761           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 10     HLG-0764           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 11     HLG-0673                       BUZWAIR GENERAL TRADING LLC
# 12     HLG-0715                                                NaN
# 13     HLG-0747                                                NaN
# 14     HLG-0668                     EMAC ENGINEERING SERVICES LLC
# 15     HLG-0672                        FARAHI GENERAL TRADING LLC
# 16     HLG-0736                                                NaN
# 17     HLG-0659          GULF PROMPT PARTNERS GENERAL TRADING LLC
# 18     HLG-0765                                                NaN
# 19     HLG-0729                                                NaN
# 20     HLG-0667                                                NaN
# 21     HLG-0711         MAGIC BRICK BUILDING MATERIAL TRADING LLC
# 22     HLG-0742                                                NaN
# 23     HLG-0738                           MONTE STELLA TRADING LLC
# 24     HLG-0675                          NEWROZ BANEH TRADING LLC
# 25     HLG-0702                      OPAL INTERNATIONALTRADING FZE
# 26     HLG-0721                                                NaN
# 27     HLG-0731                                                NaN
# 28     HLG-0739               RAMZ AL HAQEEGA GENERAL TRADING LLC
# 29     HLG-0701                    RECAZ STAR GENERAL TRADING LLC
# ..          ...                                                ...
# 36     HLG-0674                                VIVOTEK MIDDLE EAST
# 37     HLG-0720                                                NaN
# 38  HLG-0681-CL                               TUF COMMODITIES DMCC
# 39  HLG-0763-CL               TOURANTO FLAVOURS AND FRAGRANCES FZE
# 40  HLG-0750-CL               TOURANTO FLAVOURS AND FRAGRANCES FZE
# 41  HLG-0758-CL                 TAJ AL MULOOK GENERAL TRADING LLC
# 42  HLG-0692-CL                        SOREN SKY VIEW TRADING LLC
# 43  HLG-0696-CL                                    POLY BRAND FZCO
# 44  HLG-0717-CL         PETROCHEMICALS & SOLVENTS MIDDLE EAST DMCC
# 45  HLG-0727-CL                                                NaN
# 46  HLG-0748-CL                                                NaN
# 47  HLG-0755-CL                             NORTH WEST TRADING LLC
# 48  HLG-0654-CL  MOON STONE HOME ELECTRICAL APPLIANCES TRADING LLC
# 49  HLG-0708-CL                  MDKT TRADING FZE
# 50  HLG-0663-CL                  MDKT TRADING FZE
# 51  HLG-0749-CL         LAKE VIEW BUILDING MATERIALS TRADING LLC
# 52  HLG-0700-CL               LAKE VIEW BUILDING MATERIALS LLC
# 53  HLG-0682-CL                     GREEN CITY GENERAL TRADING LLC
# 54  HLG-0759-CL                     GREEN CITY GENERAL TRADING LLC
# 55  HLG-0745-CL                                                NaN
# 56  HLG-0737-CL                                                NaN
# 57  HLG-0760-CL                               DOX TECHNOLOGIES LLC
# 58  HLG-0676-CL            DANO INTERNATIONAL TRADING LLC
# 59  HLG-0657-CL            DANO INTERNATIONAL TRADING LLC
# 60  HLG-0735-CL                                                NaN
# 61  HLG-0753-CL                  CENTURY LINK GENERAL TRADING LLC
# 62  HLG-0677-CL                                                NaN
# 63  HLG-0762-CL                 BEHOVER INFORMATION TECHNOLOGY LLC
# 64  HLG-0685-CL            ADVANCE  BANKING SOLUTIONS TRADING DMCC
# 65  HLG-0699-CL                                                NaN
#
#               cityOfRepExporter  \
# 0                  Dubai, U.A.E
# 1                  Dubai, U.A.E
# 2                  Dubai, U.A.E
# 3                           NaN
# 4                  Dubai, U.A.E
# 5                           NaN
# 6   Dubai, United Arab Emirates
# 7   Dubai, United Arab Emirates
# 8   Dubai, United Arab Emirates
# 9   Dubai, United Arab Emirates
# 10  Dubai, United Arab Emirates
# 11                 Dubai, U.A.E
# 12                          NaN
# 13                          NaN
# 14                 Dubai, U.A.E
# 15                 Dubai, U.A.E
# 16                          NaN
# 17                 Dubai, U.A.E
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21  Dubai, United Arab Emirates
# 22                          NaN
# 23                 Dubai, U.A.E
# 24                 Dubai, U.A.E
# 25                 Dubai, U.A.E
# 26                          NaN
# 27                          NaN
# 28                 Dubai, U.A.E
# 29                 Dubai, U.A.E
# ..                          ...
# 36                 Dubai, U.A.E
# 37                          NaN
# 38                 Dubai, U.A.E
# 39                 Dubai, U.A.E
# 40                 Dubai, U.A.E
# 41                 Dubai, U.A.E
# 42                 Dubai, U.A.E
# 43                 Dubai, U.A.E
# 44                 Dubai, U.A.E
# 45                          NaN
# 46                          NaN
# 47                 Dubai, U.A.E
# 48                 Dubai, U.A.E
# 49                 Dubai, U.A.E
# 50                 Dubai, U.A.E
# 51                 Dubai, U.A.E
# 52                 Dubai, U.A.E
# 53                 Dubai, U.A.E
# 54                 Dubai, U.A.E
# 55                          NaN
# 56                          NaN
# 57                 Dubai, U.A.E
# 58                 Dubai, U.A.E
# 59                 Dubai, U.A.E
# 60                          NaN
# 61                 Dubai, U.A.E
# 62                          NaN
# 63                 Dubai, U.A.E
# 64                 Dubai, U.A.E
# 65                          NaN
#
#                                              exporter  \
# 0                           ARAYMOND FLUID CONNECTION
# 1                   AnHuiarts & Crafts imp.exp.Co.Ltd
# 2                              R.B.AUTOMAZIONE S.R.L.
# 3                                  ANVERALLY AND SONS
# 4                                      New Hope Group
# 5                           BGRS TEXTILE SERVICES LLP
# 6                     SANDBOX GENERAL TRADING LIMITED
# 7                     SANDBOX GENERAL TRADING LIMITED
# 8                     SANDBOX GENERAL TRADING LIMITED
# 9                     SANDBOX GENERAL TRADING LIMITED
# 10                    SANDBOX GENERAL TRADING LIMITED
# 11                             R.B.AUTOMAZIONE S.R.L.
# 12              DMV-FONTERRA EXCIPIENTS GMBH & CO. KG
# 13              DMV-FONTERRA EXCIPIENTS GMBH & CO. KG
# 14  BALLI AHSAP URUNLERI BUILDING MALZ INS TAAH SA...
# 15                 BHAWAL STEEL & ENGINEERING COMPANY
# 16                                   GEOCLIMA S.R.L
# 17                             R.B.AUTOMAZIONE S.R.L.
# 18                     HARDY EXPORT COMPANY (PVT) LTD
# 19                                 JET PROFIT CO.,LTD
# 20              KLEBCHEMIE M. G. BECKER GMBH & CO. KG
# 21                 COLORGRES BUILDING MATERIAL CO LTD
# 22                                 MARBO ITALIA SPA
# 23                                        ACC LIMITED
# 24                                   RHI DINARIS GMBH
# 25                                KALAEI BUILDING SPA
# 26                                    P&A CORPORATION
# 27                               POINT MOBILE CO.,LTD
# 28                                     ECOLEX SDN BHD
# 29                           GTEC AUTOMOBILE PTE LTD.
# ..                                                ...
# 36                                         SENECA SRL
# 37                                ZYTOMED SYSTEM GMBH
# 38  SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 39  CHIANGZHOU WORLDTRADE CENTER REAL ESTATE CO. LTD.
# 40                                    KERAMOULD S.R.L
# 41                                   HANAFI KONSALTAN
# 42                             R.B.AUTOMAZIONE S.R.L.
# 43                  ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 44       JIANGSU KELIDA DECORATION MATERIAL CO ., LTD
# 45                              PENTAX INDUSTRIES SPA
# 46                               EURO OTC PHARMA GMBH
# 47        SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 48                             R.B.AUTOMAZIONE S.R.L.
# 49                  KAITO ENTERPRISES COMPANY LIMITED
# 50                           ORLUX IMPORT-EXPORT GMBH
# 51                                        ACC LIMITED
# 52  Chamber of Real Estate and Buildersâ Associa...
# 53                           GTEC AUTOMOBILE PTE LTD.
# 54             GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 55                                 EBC KOREA CO.,LTD
# 56                                     DRALON GMBH
# 57                                   AGULEJOS GIMENEZ
# 58  BALLI AHSAP URUNLERI BUILDING MALZ INS TAAH SA...
# 59                                    ForFarmers N.V.
# 60                       CY PRECISION INDUSTRY CO LTD
# 61  SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 62                          ARAYMOND FLUID CONNECTION
# 63                  GOODWILL INDUSTRIES INTERNATIONAL
# 64    HONG KONG WILL INTERNATIONAL INVESTMENT LIMITED
# 65            ABU DHABI FERTILIZER INDUSTRIES CO WLL
#
#                            cityOfExporter                    importer  \
# 0                        Grenoble, France  TANGSHAN YIFEI TRADING CO.
# 1                             Anhui,China  TANGSHAN YIFEI TRADING CO.
# 2                           Genova, Italy  TANGSHAN YIFEI TRADING CO.
# 3                      Colombo, Sri Lanka  TANGSHAN YIFEI TRADING CO.
# 4                      Gansu Sheng, China  TANGSHAN YIFEI TRADING CO.
# 5                          Gujarat, India  TANGSHAN YIFEI TRADING CO.
# 6                        Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 7                        Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 8                        Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 9                        Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 10                       Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 11                          Genova, Italy  TANGSHAN YIFEI TRADING CO.
# 12                          Goch, Germany  TANGSHAN YIFEI TRADING CO.
# 13                          Goch, Germany  TANGSHAN YIFEI TRADING CO.
# 14                         Ankara, Turkey  TANGSHAN YIFEI TRADING CO.
# 15                          Mumbai, India  TANGSHAN YIFEI TRADING CO.
# 16                         Gorizia, Italy  TANGSHAN YIFEI TRADING CO.
# 17                          Genova, Italy  TANGSHAN YIFEI TRADING CO.
# 18                    Panadura, Sri Lanka  TANGSHAN YIFEI TRADING CO.
# 19                       Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 20                    Weingarten, Germany  TANGSHAN YIFEI TRADING CO.
# 21                     Foshan City, China  TANGSHAN YIFEI TRADING CO.
# 22                           Pavia, Italy  TANGSHAN YIFEI TRADING CO.
# 23                          Mumbai, India  TANGSHAN YIFEI TRADING CO.
# 24                     Wiesbaden, Germany  TANGSHAN YIFEI TRADING CO.
# 25                  Auckland, New Zealand  TANGSHAN YIFEI TRADING CO.
# 26                     Seoul, South Korea  TANGSHAN YIFEI TRADING CO.
# 27                     Seoul, South Korea  TANGSHAN YIFEI TRADING CO.
# 28                  Pulau Indah, Malaysia  TANGSHAN YIFEI TRADING CO.
# 29                          Padova, Italy  TANGSHAN YIFEI TRADING CO.
# ..                                    ...                         ...
# 36                           Padua, Italy  TANGSHAN YIFEI TRADING CO.
# 37                        Berlin, Germany  TANGSHAN YIFEI TRADING CO.
# 38                       Liaocheng, China  TANGSHAN YIFEI TRADING CO.
# 39                         Jiangsu, China  TANGSHAN YIFEI TRADING CO.
# 40                    Castellarano, Italy  TANGSHAN YIFEI TRADING CO.
# 41  Bandar Seri Begawan, Brunei Darusalam  TANGSHAN YIFEI TRADING CO.
# 42                          Genova, Italy  TANGSHAN YIFEI TRADING CO.
# 43                            Anhui,China  TANGSHAN YIFEI TRADING CO.
# 44                         Jiangsu, China  TANGSHAN YIFEI TRADING CO.
# 45                          Verona, Italy  TANGSHAN YIFEI TRADING CO.
# 46                         Bönen, Germany  TANGSHAN YIFEI TRADING CO.
# 47                        Shanghai, China  TANGSHAN YIFEI TRADING CO.
# 48                          Genova, Italy  TANGSHAN YIFEI TRADING CO.
# 49                       Hong Kong, China  TANGSHAN YIFEI TRADING CO.
# 50             Frankfurt Am Main, Germany  TANGSHAN YIFEI TRADING CO.
# 51                          Mumbai, India  TANGSHAN YIFEI TRADING CO.
# 52                    Quezon, Philippines  TANGSHAN YIFEI TRADING CO.
# 53                          Padova, Italy  TANGSHAN YIFEI TRADING CO.
# 54                         Guandong China  TANGSHAN YIFEI TRADING CO.
# 55               Gyeonggi,Do, South Korea  TANGSHAN YIFEI TRADING CO.
# 56                        Lingen, Germany  TANGSHAN YIFEI TRADING CO.
# 57                          Murcia, Spain  TANGSHAN YIFEI TRADING CO.
# 58                         Ankara, Turkey  TANGSHAN YIFEI TRADING CO.
# 59                    Lochem, Netherlands  TANGSHAN YIFEI TRADING CO.
# 60                         Taipei, Taiwan  TANGSHAN YIFEI TRADING CO.
# 61                       Liaocheng, China  TANGSHAN YIFEI TRADING CO.
# 62                       Grenoble, France  TANGSHAN YIFEI TRADING CO.
# 63                        Sacramento, Usa  TANGSHAN YIFEI TRADING CO.
# 64                      Changchung, China  TANGSHAN YIFEI TRADING CO.
# 65       Abu Dhabi , United Arab Emirates  TANGSHAN YIFEI TRADING CO.
#
#           cityOfImporter                        repImporter cityOfrepImporter  \
# 0   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC      Dubai, U.A.E
# 1   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 2   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 3   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 4   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 5   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 6   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 7   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 8   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 9   Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 10  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 11  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 12  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 13  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 14  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 15  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 16  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 17  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 18  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 19  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 20  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 21  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 22  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 23  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 24  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 25  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 26  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 27  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 28  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 29  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# ..                   ...                                ...               ...
# 36  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 37  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 38  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 39  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 40  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 41  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 42  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 43  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 44  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 45  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 46  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 47  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 48  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 49  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 50  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 51  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 52  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 53  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 54  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 55  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 56  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 57  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 58  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 59  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 60  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 61  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 62  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 63  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 64  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
# 65  Tangshan City, China  HORIZONE LINE GENERAL TRADING LLC        Dubai, UAE
#
#                            Origin     ...      p4unitp p4total  p5name p5qty  \
# 0                 Origin:  France     ...          NaN     NaN     NaN   NaN
# 1                   Origin: China     ...          NaN     NaN     NaN   NaN
# 2                  Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 3              Origin:  Sri Lanka     ...          NaN     NaN     NaN   NaN
# 4                  Origin:  China     ...          NaN     NaN     NaN   NaN
# 5                  Origin:  India     ...          NaN     NaN     NaN   NaN
# 6                  Origin:  China     ...          NaN     NaN     NaN   NaN
# 7                  Origin:  China     ...          NaN     NaN     NaN   NaN
# 8                  Origin:  China     ...          NaN     NaN     NaN   NaN
# 9                  Origin:  China     ...          NaN     NaN     NaN   NaN
# 10                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 11                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 12               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 13               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 14                Origin:  Turkey     ...          NaN     NaN     NaN   NaN
# 15                 Origin:  India     ...          NaN     NaN     NaN   NaN
# 16                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 17                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 18             Origin:  Sri Lanka     ...          NaN     NaN     NaN   NaN
# 19                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 20               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 21                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 22                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 23                 Origin:  India     ...          NaN     NaN     NaN   NaN
# 24               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 25           Origin:  New Zealand     ...          NaN     NaN     NaN   NaN
# 26           Origin:  South Korea     ...          NaN     NaN     NaN   NaN
# 27           Origin:  South Korea     ...          NaN     NaN     NaN   NaN
# 28              Origin:  Malaysia     ...          NaN     NaN     NaN   NaN
# 29                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# ..                            ...     ...          ...     ...     ...   ...
# 36                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 37               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 38                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 39                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 40                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 41      Origin:  Brunei Darusalam     ...          NaN     NaN     NaN   NaN
# 42                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 43                  Origin: China     ...          NaN     NaN     NaN   NaN
# 44                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 45                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 46               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 47                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 48                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 49                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 50               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 51                 Origin:  India     ...          NaN     NaN     NaN   NaN
# 52           Origin:  Philippines     ...          NaN     NaN     NaN   NaN
# 53                 Origin:  Italy     ...          NaN     NaN     NaN   NaN
# 54         Origin: Guandong China     ...          NaN     NaN     NaN   NaN
# 55        Origin: Do- South Korea     ...          NaN     NaN     NaN   NaN
# 56               Origin:  Germany     ...          NaN     NaN     NaN   NaN
# 57                 Origin:  Spain     ...          NaN     NaN     NaN   NaN
# 58                Origin:  Turkey     ...          NaN     NaN     NaN   NaN
# 59           Origin:  Netherlands     ...          NaN     NaN     NaN   NaN
# 60                Origin:  Taiwan     ...          NaN     NaN     NaN   NaN
# 61                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 62                Origin:  France     ...          NaN     NaN     NaN   NaN
# 63                   Origin:  Usa     ...          NaN     NaN     NaN   NaN
# 64                 Origin:  China     ...          NaN     NaN     NaN   NaN
# 65  Origin:  United Arab Emirates     ...          NaN     NaN     NaN   NaN
#
#    p5unit  p5unitp p5total  numOfClient  currency         date
# 0     NaN      NaN     NaN          NaN       AED   2-Feb-2019
# 1     NaN      NaN     NaN          NaN       AED  19-Feb-2019
# 2     NaN      NaN     NaN          NaN       AED   2-Feb-2019
# 3     NaN      NaN     NaN          NaN      EURO  12-Feb-2019
# 4     NaN      NaN     NaN          NaN       AED  21-Feb-2019
# 5     NaN      NaN     NaN          NaN      EURO  21-Feb-2019
# 6     NaN      NaN     NaN          3.7       AED  18-Feb-2019
# 7     NaN      NaN     NaN          3.7       AED  19-Feb-2019
# 8     NaN      NaN     NaN          3.7       AED  21-Feb-2019
# 9     NaN      NaN     NaN          3.7       AED  12-Feb-2019
# 10    NaN      NaN     NaN          3.7       AED  21-Feb-2019
# 11    NaN      NaN     NaN          NaN       AED   6-Feb-2019
# 12    NaN      NaN     NaN          NaN      EURO   6-Feb-2019
# 13    NaN      NaN     NaN          NaN      EURO  21-Feb-2019
# 14    NaN      NaN     NaN          NaN       AED   2-Feb-2019
# 15    NaN      NaN     NaN          NaN       AED   6-Feb-2019
# 16    NaN      NaN     NaN          NaN      EURO  18-Feb-2019
# 17    NaN      NaN     NaN          NaN       AED   4-Feb-2019
# 18    NaN      NaN     NaN          NaN       USD   7-Feb-2019
# 19    NaN      NaN     NaN          NaN      EURO  14-Feb-2019
# 20    NaN      NaN     NaN          NaN      EURO   4-Feb-2019
# 21    NaN      NaN     NaN         14.9       AED  17-Feb-2019
# 22    NaN      NaN     NaN          NaN      EURO  20-Feb-2019
# 23    NaN      NaN     NaN          NaN      EURO  19-Feb-2019
# 24    NaN      NaN     NaN          NaN       AED   6-Feb-2019
# 25    NaN      NaN     NaN          NaN       AED  13-Feb-2019
# 26    NaN      NaN     NaN          NaN      EURO   9-Feb-2019
# 27    NaN      NaN     NaN          NaN      EURO  14-Feb-2019
# 28    NaN      NaN     NaN          NaN      EURO  19-Feb-2019
# 29    NaN      NaN     NaN          NaN       AED  13-Feb-2019
# ..    ...      ...     ...          ...       ...          ...
# 36    NaN      NaN     NaN          NaN       AED   6-Feb-2019
# 37    NaN      NaN     NaN          NaN      EURO   7-Feb-2019
# 38    NaN      NaN     NaN          NaN       AED  18-Feb-2019
# 39    NaN      NaN     NaN          NaN       AED  19-Feb-2019
# 40    NaN      NaN     NaN          NaN       AED  18-Feb-2019
# 41    NaN      NaN     NaN          NaN       AED   5-Feb-2019
# 42    NaN      NaN     NaN          NaN       AED   4-Feb-2019
# 43    NaN      NaN     NaN          NaN       AED   6-Feb-2019
# 44    NaN      NaN     NaN          NaN      EURO   7-Feb-2019
# 45    NaN      NaN     NaN          NaN      EURO   7-Feb-2019
# 46    NaN      NaN     NaN          NaN      EURO  13-Feb-2019
# 47    NaN      NaN     NaN          NaN       AED  13-Feb-2019
# 48    NaN      NaN     NaN          NaN       AED   4-Feb-2019
# 49    NaN      NaN     NaN          NaN       AED   5-Feb-2019
# 50    NaN      NaN     NaN          NaN       AED  16-Feb-2019
# 51    NaN      NaN     NaN          NaN       AED  13-Feb-2019
# 52    NaN      NaN     NaN          NaN       AED   2-Feb-2019
# 53    NaN      NaN     NaN          NaN       AED  18-Feb-2019
# 54    NaN      NaN     NaN          NaN       AED   7-Feb-2019
# 55    NaN      NaN     NaN          NaN      EURO  19-Feb-2019
# 56    NaN      NaN     NaN          NaN      EURO  16-Feb-2019
# 57    NaN      NaN     NaN          NaN       AED   9-Feb-2019
# 58    NaN      NaN     NaN          NaN       AED   5-Feb-2019
# 59    NaN      NaN     NaN          NaN       AED   5-Feb-2019
# 60    NaN      NaN     NaN          NaN      EURO  14-Feb-2019
# 61    NaN      NaN     NaN          NaN       AED  19-Feb-2019
# 62    NaN      NaN     NaN          NaN       AED   4-Feb-2019
# 63    NaN      NaN     NaN          NaN       AED  17-Feb-2019
# 64    NaN      NaN     NaN          NaN       AED  19-Feb-2019
# 65    NaN      NaN     NaN          NaN       AED   6-Feb-2019
#
# [66 rows x 42 columns]

# %%
client = pd.read_csv('2018 ABACUS CLIENTS.csv')
client.plot()

# %%
def lcs(X , Y): 
    # find the length of the strings 
    m = len(X) 
    n = len(Y) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n+1) for i in range(m+1)] 
  
    """Following steps build L[m+1][n+1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j] , L[i][j-1]) 
    return L[m][n] 
#end of function lcs

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    for char in clientlist.loc[c,'LIST OF COMPANY']:
        if char != '.':
            num = num + char
        else:
            break
    return num
    
def bestmatch(candid,clientlist):
    # Remove all bad charachters.
    candid = ''.join(e for e in candid if e.isalnum())
    c = 0
    maxAl = 0
    candidRow = []
    num = ''
    maxLCStoClient = 0
    for client in clientlist['LIST OF COMPANY']:

        candidLcs = lcs(candid.lower(), client.lower())
        LCStoClient = candidLcs / len(client)
        if (candidLcs == len(candid)):
            if (maxLCStoClient < LCStoClient):
                candidRow = list(clientlist.iloc[c])
                num = getClientRef(c, clientlist)
                maxLCStoClient = LCStoClient
        c+=1


    return num, candidRow
# bestmatch('ANA GENERAL TRADING LLC',client)

# %%
#Finding major company of REP.
def majorCoOfREP(candid,client):
    bestmatch(candid,client)
    return ''

# %%
def ordinal(date):
    if date == 1:
        ordin = 'ST'
    elif date == 2:
        ordin = 'ND'
    elif date == 3:
        ordin = 'RD'
    else:
        ordin = 'TH'
    return ordin

# %%
def amontformat(totamount):
    c = len(totamount) - 1
    buf = ''
    for i in range(c+1):
        if totamount[c - i] == '.':
            buf = totamount[c - i] + buf
            try:
                totamount1 = totamount.replace(buf,'')
#                 print(buf , totamount1)
            except:
                1+1
            if len(buf)<2:
                buf = buf[1:]
                buf = '.' +'00'
            elif len(buf) < 3:
                buf = buf[1:]
                buf = '.' + buf +'0'
            buf =  buf[:3]
            c1 = len(totamount1) -1
            count = 1
            buf1 = ''
            for j in range(c1+1):
                if count%3 == 0:
                    buf1 = ',' + totamount1[c1 - j] + buf1
                else:
                    buf1 = totamount1[c1 - j] + buf1
                count += 1
#             print(buf1)
            break
        else:
            buf = totamount[c - i] + buf
    return buf1 + buf

# %%
def produceDocxFile(num,ref):
    #Title
    document =  Document('HORIZENE LINE.docx')
    paragraph = document.add_paragraph('\n \n \n \n')
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('PURCHASE AND SALE AGREEMENT')
    run.bold = True
    font = run.font
    font.name = 'Arial'
    font.size = Pt(14)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    style = document.styles['Normal']
    font = style.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('BY AND BETWEEN')
    run.bold = True

    #buyer
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run(str(buyerName)+', '+buyerCity)
    run.bold = True

    #repBuyer
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run1= paragraph.add_run('Represented by: ')

    run= paragraph.add_run(str(buyerRep)+', '+buyerRepCity)
    run.bold = True

    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('AND')
    run.bold = True

    #source
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run( sellerName+', '+sellerCity)
    run.bold = True

    #rep source
    if (str(sellerRep) != str(np.nan)):
    #     print(np.nan, sellerRep)
        paragraph = document.add_paragraph()
        par_format = paragraph.paragraph_format
        par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
        run1= paragraph.add_run('Represented by: ')
        run1.bold = True
        run= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
        run.bold = True


    #THIS PURCHASE AND SALE AGREEMENT is entered into this 8TH day of December 2018, by and between 
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run= paragraph.add_run('THIS PURCHASE AND SALE AGREEMENT is entered into this '+adate+', by and between ')

    run1= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
    run1.bold = True

    run2= paragraph.add_run('Represented by: ')

    run3= paragraph.add_run(str(buyerRep)+', '+buyerRepCity+ ' ')
    run3.bold = True

    run4= paragraph.add_run('(hereinafter referred as "Buyer") with office address at the United Arab Emirates and ')

    run5= paragraph.add_run(sellerName+', '+sellerCity)
    run5.bold = True

    if (str(sellerRep) != str(np.nan)):
        run6= paragraph.add_run(' Represented by: ')

        run7= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
        run7.bold = True
    run4= paragraph.add_run(' (hereinafter referred as "Seller”) with office address at the United Arab Emirates. ')

    #RECITALS:
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run= paragraph.add_run('RECITALS:')
    run.bold = True

    #WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY and
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA represented 
    #BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E can enter into this Sale and Purchase Agreement
    #and sign pertinent documents with full rights under terms and conditions specified therein;
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('WHEREAS')
    run0.bold = True

    run1= paragraph.add_run(', the ')

    run4= paragraph.add_run(sellerName+', '+sellerCity )
    run4.bold = True

    if (str(sellerRep) != str(np.nan)):
        run2= paragraph.add_run(' Represented by: ')

        run3= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity) + ' and ')
        run3.bold = True

    run6= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
    run6.bold = True

    run7= paragraph.add_run('Represented by: ')

    run8= paragraph.add_run(str(buyerRep)+', '+buyerRepCity+ ' ')
    run8.bold = True

    run7= paragraph.add_run(' can enter into this Sale and Purchase Agreement and sign pertinent documents with full ' +
                            'rights under terms and conditions specified therein;')
    font = run7.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #WHEREAS, the SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY desires to sell the Products
    #defined below and the SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA desires
    #to purchase the Products from SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY.
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('WHEREAS')
    run0.bold = True

    run1= paragraph.add_run(', the ')

    run2= paragraph.add_run(sellerName+', '+sellerCity )
    run2.bold = True

    run3= paragraph.add_run(' desires to sell the Products defined below and the ')

    run4= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
    run4.bold = True

    run5= paragraph.add_run(' desires to purchase the Products from ')

    run6= paragraph.add_run(sellerName+', '+sellerCity + '. ')
    run6.bold = True
    font = run6.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #NOW THEREFORE, in consideration of the mutual covenants and the agreements herein contained and other
    #goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows:
    paragraph = document.add_paragraph()
    par_format = paragraph.paragraph_format
    par_format.first_line_indent = Inches(0.27)
    run0= paragraph.add_run('NOW THEREFORE')
    run0.bold = True

    run1= paragraph.add_run(', in consideration of the mutual covenants and the agreements herein contained and other '
    + 'goods and valuable (the receipt and sufficiency of which are hereby acknowledged) the parties agree as follows: ')
    font = run1.font
    font.name = 'Nirmala UI'
    font.size = Pt(9)
    font.color.rgb = RGBColor(0x0, 0x0, 0x0)

    #Sale of Product.  SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY hereby sells to
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA and 
    # SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA hereby purchases from
    # SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY the product details below:
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Sale of Product.')
    run0.bold = True
    run0.underline = True

    run1 = paragraph.add_run(' ' +sellerName+', '+sellerCity)
    run1.bold = True

    run2= paragraph.add_run(' hereby sells to ' )

    run4= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
    run4.bold = True

    run5= paragraph.add_run(' and ' )

    run6= paragraph.add_run(str(buyerName)+', '+buyerCity+ ' ')
    run6.bold = True

    run7= paragraph.add_run(' hereby purchases from ' )

    run8= paragraph.add_run( sellerName+', '+sellerCity )
    run8.bold = True

    run9= paragraph.add_run(' the product details below: ' )

    # p = document.add_paragraph('A plain paragraph having some ')
    # p.add_run('bold').bold = True
    # p.add_run(' and some ')
    # p.add_run('italic.').italic = True
    records = []
    rec = []
    for i in range(len(pname)):
        rec.append(i+1)
        rec.append(pname[i])
        rec.append(pqty[i])
        rec.append(punit[i])
        rec.append(punitp[i])
        rec.append(ptotal[i])
        records.append(rec)
        rec = []

    # document.styles['OR']
    table = document.add_table(rows=1, cols=6, style='Table Grid')
    hdr_cells = table.rows[0].cells
    hdr_cells[0].text = 'SR. NO.'
    hdr_cells[1].text = 'DESCRIPTION'
    hdr_cells[2].text = 'QTY'
    hdr_cells[3].text = 'UNIT OF MEASUREMENT'
    hdr_cells[4].text = 'UNIT PRICE'
    hdr_cells[5].text = 'AMOUNT'

    c = 0
    for SR, DESCRIPTION, UNITOFM, qty, UNITPRICE, AMOUNT in records:
        if c ==1:
            paragraph = document.add_paragraph('\n \n \n \n \n')
            table = document.add_table(rows=1, cols=6, style='Table Grid')
            hdr_cells = table.rows[0].cells
            hdr_cells[0].text = 'SR. NO.'
            hdr_cells[1].text = 'DESCRIPTION'
            hdr_cells[2].text = 'QTY'
            hdr_cells[3].text = 'UNIT OF MEASUREMENT'
            hdr_cells[4].text = 'UNIT PRICE'
            hdr_cells[5].text = 'AMOUNT'

        c += 1 
        row_cells = table.add_row().cells
        row_cells[0].text = str(SR)
        row_cells[1].text = DESCRIPTION
        row_cells[2].text = str(UNITOFM)
        row_cells[3].text = qty
        row_cells[4].text = str(currency + ' ' + UNITPRICE)
        row_cells[5].text = str(currency + ' ' + str(AMOUNT))
    for row in table.rows:
        for cell in row.cells:
            paragraphs = cell.paragraphs
            for paragraph in paragraphs:
                par_format = paragraph.paragraph_format
                par_format.alignment = WD_ALIGN_PARAGRAPH.CENTER            
                for run in paragraph.runs:
                    font = run.font
                    font.name = 'Arial Narrow'
                    font.size= Pt(10)
                    font.color.rgb = RGBColor(0x0, 0x0, 0x0)
    for cell in table.rows[0].cells:
        paragraphs = cell.paragraphs
        for paragraph in paragraphs:
            for run in paragraph.runs:
                run.bold = True
    if len(records) == 1:
        paragraph = document.add_paragraph('\n \n \n \n')

    #2. Purchase Price.   SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA shall pay
    #to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY for the Products and for all obligations
    #specified herein, as full and complete consideration therefore, the sum of €      88,474.00 
    #(EIGHTY EIGHT THOUSAND FOUR HUNDRED SEVENTY FOUR EUROS ONLY).
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Purchase Price.')
    run0.bold = True
    run0.underline = True

    run1 = paragraph.add_run(' ' + str(buyerName)+', '+buyerCity+ ' ')
    run1.bold = True

    run2= paragraph.add_run('shall pay to ' )

    run4= paragraph.add_run( sellerName+', '+sellerCity )
    run4.bold = True

    run5= paragraph.add_run(' for the Products and for all obligations specified herein, as full ' + 
                            'and complete consideration therefore, the sum of ' )

    run6= paragraph.add_run(currency + ' ' + str(totamount))
    run6.bold = True

    run7= paragraph.add_run(' (' + amountToWord + ').')


    #3.Payment.  Payment of the Purchase Price shall be made by 
    #SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA or its representative 
    #BEYZADE GENERAL TRADING L.L.C - DUBAI, U.A.E to SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY 
    #in full payment in advance before the delivery date.
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Payment.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' Payment of the Purchase Price shall be made by ' )

    run2= paragraph.add_run( str(buyerName)+', '+buyerCity )
    run2.bold = True

    run3= paragraph.add_run(' or its representative ')
    run3.bold = False

    run4= paragraph.add_run( str(buyerRep)+', '+buyerRepCity )
    run4.bold = True

    run5= paragraph.add_run(' to ')

    run6= paragraph.add_run( sellerName+', '+sellerCity )
    run6.bold = True

    if (str(sellerRep) != str(np.nan)):
        run7= paragraph.add_run(' or its representative  ' )
        run8= paragraph.add_run(str(sellerRep)+', '+str(sellerRepCity))
        run8.bold = True
    run9= paragraph.add_run(' in full payment in advance before the delivery date.')


    #Acceptance.   “Acceptance" of the Product shall be deemed to occur on the date when, in the reasonable
    #opinion of SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD - SHANGHAI, CHINA the Product conforms 
    #to the Specifications, and has continuously operated in compliance with the Specifications for thirty (30) 
    #days after Product Turnover
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Acceptance.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' “Acceptance" of the Product shall be deemed to occur on the date when, '+
                            'in the reasonable opinion of ' )

    run2= paragraph.add_run(str(buyerName)+', '+buyerCity)
    run2.bold = True

    run4= paragraph.add_run(' the Product conforms to the Specifications, and has continuously operated in compliance ' + 
                            'with the Specifications for thirty (30) days after Product Turnover.' )

    #Indemnification. In the event either party breaches or is deemed to have breached any of the 
    #representations and warranties contained in this Agreement, or fails to perform or comply with any
    #of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and
    #defend the other party, and its directors, officers, shareholders, attorneys, representatives and
    #agents, from and against any damages incurred by the non-defaulting party. 
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('Indemnification.')
    run0.bold = True
    run0.underline = True

    run1= paragraph.add_run(' In the event either party breaches or is deemed to have breached any of the '+
    'representations and warranties contained in this Agreement, or fails to perform or comply with any'+
    ' of the covenants and agreements set forth in this Agreement, it shall hold harmless, indemnify and'+
    ' defend the other party, and its directors, officers, shareholders, attorneys, representatives and'+
    ' agents, from and against any damages incurred by the non-defaulting party.')


    #General. SAUREX SPINNING SOULUTION GMBH & CO.KG - GILCHING, GERMANY shall perform this Agreement
    #in compliance with all applicable local laws, rules, regulations, and ordinances, and represents that
    #it shall have obtained all licenses and permits required by law to engage in the activities necessary
    #to perform its obligations under this Agreement.  
    paragraph = document.add_paragraph()
    styles = document.styles
    paragraph.style = document.styles['List Paragraph']

    par_format = paragraph.paragraph_format

    run0= paragraph.add_run('General.')
    run0.bold = True
    run0.underline = True

    run2 = paragraph.add_run(' ' + sellerName+', '+sellerCity + ' ')
    run2.bold = True

    run1= paragraph.add_run('shall perform this Agreement in compliance with all applicable local laws'+
                            ', rules, regulations, and ordinances, and represents that it shall have ' + 
                            'obtained all licenses and permits required by law to engage in the activities ' +
                            'necessary to perform its obligations under this Agreement. ' )
    s = ''
    for i in range(6-len(records)):
        s += '\n'
    paragraph = document.add_paragraph(s)
    paragraph = document.add_paragraph(int(1.33 * len(sellerName+', '+sellerCity))*'_' + '\n')
    run0= paragraph.add_run(sellerName+', '+sellerCity)
    run0.bold = True

    # document.add_picture('sign.png', width=Inches(2))
    paragraph = document.add_paragraph('\n \n \n \n \n')
    paragraph = document.add_paragraph(int(1.33 * len(str(buyerName)+', '+buyerCity)) * '_'+'\n')
    run0= paragraph.add_run(str(buyerName)+', '+buyerCity)
    run0.bold = True

    document.save('output/' + str(ref) + '.docx')

# %%
#PO tracking sheet
vect = []
for co in range(len(track['REF'])):
    vector = list(track.loc[co])
    sellerRep = vector[1]
    sellerRepCity = vector[2]
    try:
        sellerRepCity = sellerRepCity.replace('-',',')
    except:
        1+1
    try:
        sellerRepCity = sellerRepCity.lower()
        sellerRepCity = sellerRepCity.replace('uae','U.A.E')
        sellerRepCity = sellerRepCity.upper()
    except:
        1+1

    sellerName = vector[3]
    sellerCity = vector[4]
    try:
        sellerCity = sellerCity.replace('-',',')
    except:
        1+1
    try:
        sellerCity = sellerCity.lower()
        sellerCity = sellerCity.replace('uae','U.A.E')
        sellerCity = sellerCity.upper()
    except:
        1+1

    buyerName = vector[5]
    buyerCity = vector[6]
    try:
        buyerCity = buyerCity.replace('-',',')
    except:
        1+1
    try:
        buyerCity = buyerCity.lower()
        buyerCity = buyerCity.replace('uae','U.A.E')
        buyerCity = buyerCity.upper()
    except:
        1+1
    buyerRep = vector[7]
    buyerRepCity = vector[8]
    try:
        buyerRepCity = buyerRepCity.replace('-',',')
    except:
        1+1
    try:
        buyerRepCity = buyerRepCity.lower()
        buyerRepCity = buyerRepCity.replace('uae','U.A.E')
        buyerRepCity = buyerRepCity.upper()
    except:
        1+1
    fdate = vector[41]
#     print(fdate)
    adate = ''
    for ch in fdate:
        if ch !='-':
            adate = adate + ch
        else:
            try:
                adate = adate + ordinal(int(adate)) + ' day of '
            except:
                adate = adate + ' '
    product = vector[14:39]
    product
    pname = []
    pqty = []
    punit = []
    punitp = []
    ptotal = []
    cur = []
    for i in range(5):
        if not str(product[i*5]) == str(np.nan):
            pname.append(product[i*5])
            pqty.append(product[i*5 +1])
            punit.append(product[i*5+2])
            punitp.append(amontformat(str(product[i*5+3])))
            ptotal.append(amontformat(str(product[i*5+4])))
    currency = vector[40]
    totamount = vector[12]
    #money format
    totamount = amontformat(str(totamount))
    amountToWord = vector[13]
    produceDocxFile(co, track.loc[co, 'REF']))
# Out:
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
# 21-Feb-2019
